# %% [markdown]
# # Qiskit: Transpilation and IR Gen
# Qiskit abstracts away many aspects of the quantum compilation process, allowing us to interface with complex systems with a bit of simple python. To use Qiskit, the workflow is generally:
#
# 1. Create a quantum circuit
# 2. Transpile the circuit onto a backend of choice (either a simulated backend or real quantum hardware)
# 3. Execute the circuit on the chosen backend
# 4. Get the results of the executed quantum circuit.
#
# In this tutorial, we will take an in depth look at step 2, transpilation.
#
# It all starts by first installing the Qiskit package:

# %%
pip install qiskit

# %%
# 1) Create a simple quantum circuit.

from qiskit import QuantumCircuit
from qiskit.visualization import circuit_drawer

qc = QuantumCircuit(5)
qc.h(0)
qc.cx(0,range(1,5))
qc.measure_all()
qc.draw()
# Out:
#         ┌───┐                     ░ ┌─┐
#    q_0: ┤ H ├──■────■────■────■───░─┤M├────────────
#         └───┘┌─┴─┐  │    │    │   ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──┼────┼────┼───░──╫─┤M├─────────
#              └───┘┌─┴─┐  │    │   ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├──┼────┼───░──╫──╫─┤M├──────
#                   └───┘┌─┴─┐  │   ░  ║  ║ └╥┘┌─┐
#    q_3: ───────────────┤ X ├──┼───░──╫──╫──╫─┤M├───
#                        └───┘┌─┴─┐ ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ────────────────────┤ X ├─░──╫──╫──╫──╫─┤M├
#                             └───┘ ░  ║  ║  ║  ║ └╥┘
# meas: 5/═════════════════════════════╩══╩══╩══╩══╩═
#                                      0  1  2  3  4

# %%
# 2) Transpile the circuit onto a backend with simulated noise.
# For more information about these "simulated noisy backends", see
# https://qiskit.org/documentation/tutorials/simulators/2_device_noise_simulation.html
# For more information about transpilation... keep reading!

from qiskit.test.mock import FakeBoeblingen
from qiskit.compiler import transpile

simulated_backend = FakeBoeblingen()
transpiled_qc = transpile(qc, simulated_backend, optimization_level=0)

# %%
# 3) Now, we can execute the transpiled circuit on the simulated noisy backend
results = simulated_backend.run(transpiled_qc).result()

# %%
# 4) Finally, get the results of the executed circuit. Since our circuit entangles all the qubits,
# We should be aiming for a 50/50 split between the |00000> and |11111> states. Of course, due
# to the simulated noise we won't quite achieve that
from qiskit.tools.visualization import plot_histogram

counts = results.get_counts()
plot_histogram(counts)

# %% [markdown]
# In this introductory section, we simply created, transpiled, and executed a simple quantum circuit, then printed the results at the end. In the rest of this tutorial we will focus on the transpilation step, what goes on behind the scenes, why it is important to overall compilation and how it can meaningfully affect results.

# %% [markdown]
# # Transpilation: What is it?
#
# As the prefix suggests, transpilation differs from compilation in that it moves code laterally, rather than vertically. While compilation normally takes in a high-level source and spits out a low level target program, transpilation's input and output are of comparable complexity. In our case, the Qiskit transpiler injests one quantum circuit and spits out an optimized version of that circuit after having performed several transformative passes.
#
# ![Transpilation Passes](transpiling_core_steps.png)
#
#
# Note: See [here](https://qiskit.org/documentation/apidoc/transpiler.html) for more information about the transpilation process.
#
# ###  Hardware Dependency
# Earlier, we ran
# ```{python}
# simulated_backend = FakeBoeblingen()
# transpiled_qc = transpile(qc, simulated_backend, optimization_level=0)
# ```
# Note that the transpile function takes a ``backend`` parameter. It uses this information in order to optimize the quantum circuit according to the particular hardware the quantum circuit will be running on. Therefore, the transpilation process is **"hardware aware"**.
#
# ### What Other Parameters Does `transpile()` Take?
# The `transpile()` function has another parameter called `optimization_level`, which specifies a predefined transpilation process, or a predefined sequence of transformative passes. As shown earlier, the transpilation process involves gate optimization, device connectivity optimization, and more - in fact, it's a somewhat daunting list. Again, Qiskit abstracts these concepts away and allows a quantum programmer to use one of four predefined transpilation processes without fiddling with the details. By default `optimization_level = 1`, but we can set it to four different values as shown here:
# ```{python}
# simulated_backend = FakeBoeblingen()
# transpiled_qc0 = transpile(qc, simulated_backend, optimization_level=0)  # No Optimization
# transpiled_qc1 = transpile(qc, simulated_backend, optimization_level=1)  # Some Optimization
# transpiled_qc2 = transpile(qc, simulated_backend, optimization_level=2)  # More Optimization
# transpiled_qc3 = transpile(qc, simulated_backend, optimization_level=3)  # Maximum Optimization
# ```
#
# Note: See [here](https://qiskit.org/documentation/stubs/qiskit.compiler.transpile.html) for more information about the `traspiler()` parameters.
#
# These optimizations do work - even with this very simple circuit which doesn't have much room for optimization, you should be able to see a bump in the percentages of the desired answers.

# %%
# 2) Lets transpile our previous circuit again using the most advanced predefined transpilation process, optimization_level=3
transpiled_qc3 = transpile(qc, simulated_backend, optimization_level=3)

# 3) Lets execute the transpiled circuit on the simulated noisy backend
results = simulated_backend.run(transpiled_qc3).result()

# 4) Lets get the results of the executed circuit
counts = results.get_counts()
plot_histogram(counts)

# %% [markdown]
# As you can see, in general you will find that the transpiled circuit using optimization_level=3 produces more accurate probabilities than a transpiled circuit using optimization_level=0.

# %% [markdown]
# # Example 1: Bernstein-Vazirani Circuit for 3 bit hidden string s
# Here we will go over a small circuit that implements the [Bernstein-Vazirani](https://en.wikipedia.org/wiki/Bernstein%E2%80%93Vazirani_algorithm) algorithm for a 3 bit hidden string s.

# %%
s = '011'   # the hidden binary string
n = 3 # number of bits used to represent s


# We need a circuit with n qubits, plus one auxiliary qubit
# We also need n classical bits to receive the output
qc = QuantumCircuit(n+1, n)

# Put auxiliary in the minus state |->
# We leave the other n qubits in just |0>
qc.h(n)
qc.z(n)

# Apply Hadamard gates to each of the n "main" qubits (excluding the auxiliary)
# before querying the oracle
for i in range(n):
    qc.h(i)
    
# Apply barrier
qc.barrier()

# Apply the inner-product oracle
s = s[::-1] # reverse s to fit qiskit's qubit ordering
for q in range(n):
    if s[q] == '0':
        qc.i(q)
    else:
        qc.cx(q, n)
        
# Apply barrier
qc.barrier()

# Apply Hadamard gates after querying the oracle
for i in range(n):
    qc.h(i)


# Measurement
for i in range(n):
    qc.measure(i, i)


qc.draw()
# Out:
#      ┌───┐      ░                 ░ ┌───┐┌─┐
# q_0: ┤ H ├──────░───■─────────────░─┤ H ├┤M├──────
#      ├───┤      ░   │             ░ ├───┤└╥┘┌─┐
# q_1: ┤ H ├──────░───┼─────────■───░─┤ H ├─╫─┤M├───
#      ├───┤      ░   │  ┌───┐  │   ░ ├───┤ ║ └╥┘┌─┐
# q_2: ┤ H ├──────░───┼──┤ I ├──┼───░─┤ H ├─╫──╫─┤M├
#      ├───┤┌───┐ ░ ┌─┴─┐└───┘┌─┴─┐ ░ └───┘ ║  ║ └╥┘
# q_3: ┤ H ├┤ Z ├─░─┤ X ├─────┤ X ├─░───────╫──╫──╫─
#      └───┘└───┘ ░ └───┘     └───┘ ░       ║  ║  ║
# c: 3/═════════════════════════════════════╩══╩══╩═
#                                           0  1  2

# %% [markdown]
# ### Transpilation deepdive
#
# Now, we will learn more about Qiskit's transpiler by analyzing the process undergone by the above circuit.
#
# The first order of business is choosing a backend: as we did before, we will be using the `FakeBoeblingen()` backend, which has simulated noise.
#
# For more information about Qiskit's backends, please visit:
# 1) [Backend Tutorial](https://qiskit.org/documentation/tutorials/circuits_advanced/08_gathering_system_information.html)
# 2) [Backend Config](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendConfiguration.html#qiskit.providers.models.BackendConfiguration)

# %%
# Define a simulated noisy backend
simulated_backend = FakeBoeblingen()


# Print out basic features of this backend. Note, I am using a function found in Backend_Resource2
config = simulated_backend.configuration()
print("This backend is called {0}, and is on version {1}. \nIt has {2} qubit{3}. \nIt "
      "{4} OpenPulse programs. \nThe basis gates supported on this device are {5}."
      "".format(config.backend_name,
                config.backend_version,
                config.n_qubits,
                '' if config.n_qubits == 1 else 's',
                'supports' if config.open_pulse else 'does not support',
                config.basis_gates))
# Out:
# This backend is called fake_boeblingen, and is on version 1.2.9.
# It has 20 qubits.
# It supports OpenPulse programs.
# The basis gates supported on this device are ['id', 'u1', 'u2', 'u3', 'cx'].

# %% [markdown]
# ### Logger
#
# In order to track and report information about transpilation, we'll use a `Logger` object to help us gain insight into the transpiler.

# %%
import logging

logging.basicConfig(level='DEBUG')
logging.getLogger('qiskit.transpiler').setLevel('INFO')
formatter = logging.Formatter('%(asctime)s --- %(name)s --- %(levelname)s: %(message)s\n')
handler = logging.getLogger().handlers[0]
handler.setFormatter(formatter)

# %% [markdown]
# ### No Optimization
# If we set `optimization_level = 0`, the transpiler only does very simple transformations. This level will usually give bad results, because basic sources of error are not addressed. Note the logs, printed out as we run `transpile()`: you can read through and see exactly which passes are applied to produce `transpiled_qc0`.

# %%
transpiled_qc0 = transpile(qc, simulated_backend, optimization_level=0)  # No Optimization
print('Optimization Level 0')
print('Depth:', transpiled_qc0.depth())
print('Gate counts:', transpiled_qc0.count_ops())
transpiled_qc0.draw()
# Out:
# 2022-06-27 12:46:26,917 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00000 (ms)
#
# 2022-06-27 12:46:26,922 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-06-27 12:46:26,924 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.00000 (ms)
#
# 2022-06-27 12:46:26,925 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: TrivialLayout - 0.00000 (ms)
#
# 2022-06-27 12:46:26,927 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.00000 (ms)
#
# 2022-06-27 12:46:26,931 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.99444 (ms)
#
# 2022-06-27 12:46:26,935 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 1.00136 (ms)
#
# 2022-06-27 12:46:26,937 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 1.19519 (ms)
#
# 2022-06-27 12:46:26,942 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BarrierBeforeFinalMeasurements - 2.99621 (ms)
#
# 2022-06-27 12:46:26,959 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: StochasticSwap - 14.83178 (ms)
#
# 2022-06-27 12:46:26,961 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-06-27 12:46:26,962 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-06-27 12:46:26,964 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('barrier', 20), ('barrier', 4), ('measure', 1), ('swap', 2), ('z', 1), ('id', 1), ('h', 1), ('cx', 2)} to target basis {'u1', 'reset', 'measure', 'u3', 'delay', 'barrier', 'snapshot', 'id', 'u2', 'cx'}.
#
# 2022-06-27 12:46:26,968 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.002s.
#
# 2022-06-27 12:46:26,975 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.005s.
#
# 2022-06-27 12:46:26,977 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-27 12:46:26,978 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 13.30590 (ms)
#
# 2022-06-27 12:46:26,979 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00000 (ms)
#
# 2022-06-27 12:46:26,981 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 5279.74272 (ms)
# Optimization Level 0
# Depth: 12
# Gate counts: OrderedDict([('cx', 11), ('u2', 7), ('barrier', 3), ('measure', 3), ('u1', 1), ('id', 1)])
#                  ┌─────────┐          ░      ┌───┐                         »
#         q_0 -> 0 ┤ U2(0,π) ├──────────░───■──┤ X ├──■──────────────────────»
#                  ├─────────┤          ░ ┌─┴─┐└─┬─┘┌─┴─┐          ┌───┐     »
#         q_1 -> 1 ┤ U2(0,π) ├──────────░─┤ X ├──■──┤ X ├──■────■──┤ X ├──■──»
#                  ├─────────┤          ░ └───┘┌───┐└───┘┌─┴─┐┌─┴─┐└─┬─┘┌─┴─┐»
#         q_2 -> 2 ┤ U2(0,π) ├──────────░───■──┤ X ├──■──┤ X ├┤ X ├──■──┤ X ├»
#                  ├─────────┤┌───────┐ ░ ┌─┴─┐└─┬─┘┌─┴─┐├───┤└───┘     └───┘»
#         q_3 -> 3 ┤ U2(0,π) ├┤ U1(π) ├─░─┤ X ├──■──┤ X ├┤ I ├───────────────»
#                  └─────────┘└───────┘ ░ └───┘     └───┘└───┘               »
#   ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
#                                                                            »
#   ancilla_1 -> 5 ──────────────────────────────────────────────────────────»
#                                                                            »
#   ancilla_2 -> 6 ──────────────────────────────────────────────────────────»
#                                                                            »
#   ancilla_3 -> 7 ──────────────────────────────────────────────────────────»
#                                                                            »
#   ancilla_4 -> 8 ──────────────────────────────────────────────────────────»
#                                                                            »
#   ancilla_5 -> 9 ──────────────────────────────────────────────────────────»
#                                                                            »
#  ancilla_6 -> 10 ──────────────────────────────────────────────────────────»
#                                                                            »
#  ancilla_7 -> 11 ──────────────────────────────────────────────────────────»
#                                                                            »
#  ancilla_8 -> 12 ──────────────────────────────────────────────────────────»
#                                                                            »
#  ancilla_9 -> 13 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_10 -> 14 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_11 -> 15 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_12 -> 16 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_13 -> 17 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_14 -> 18 ──────────────────────────────────────────────────────────»
#                                                                            »
# ancilla_15 -> 19 ──────────────────────────────────────────────────────────»
#                                                                            »
#             c: 3/══════════════════════════════════════════════════════════»
#                                                                            »
# «                       ░ ┌─────────┐ ░    ┌─┐
# «        q_0 -> 0 ──■───░─┤ U2(0,π) ├─░────┤M├───
# «                 ┌─┴─┐ ░ └─────────┘ ░    └╥┘
# «        q_1 -> 1 ┤ X ├─░─────────────░─────╫────
# «                 └───┘ ░ ┌─────────┐ ░ ┌─┐ ║
# «        q_2 -> 2 ──────░─┤ U2(0,π) ├─░─┤M├─╫────
# «                       ░ ├─────────┤ ░ └╥┘ ║ ┌─┐
# «        q_3 -> 3 ──────░─┤ U2(0,π) ├─░──╫──╫─┤M├
# «                       ░ └─────────┘ ░  ║  ║ └╥┘
# «  ancilla_0 -> 4 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «  ancilla_1 -> 5 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «  ancilla_2 -> 6 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «  ancilla_3 -> 7 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «  ancilla_4 -> 8 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «  ancilla_5 -> 9 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# « ancilla_6 -> 10 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# « ancilla_7 -> 11 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# « ancilla_8 -> 12 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# « ancilla_9 -> 13 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_10 -> 14 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_11 -> 15 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_12 -> 16 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_13 -> 17 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_14 -> 18 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «ancilla_15 -> 19 ────────────────────░──╫──╫──╫─
# «                                     ░  ║  ║  ║
# «            c: 3/═══════════════════════╩══╩══╩═
# «                                        0  1  2

# %% [markdown]
# The above circuit diagram is hard to read. To better visualize it, we will convert it to a **Directed Acyclic Graph (DAG)**. We need the following Qiskit packages to convert the circuit to a DAG, as well as the `pydot` library which can be installed from the terminal with `pip install pydot`.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import circuit_to_dag
from qiskit.tools.visualization import dag_drawer

# Required software to visually see DAG
# !pip install pydot

# %%
# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(transpiled_qc0)
dag_drawer(dag)

# %% [markdown]
# As you can see, we have a total of 20 quantum registers because we chose `FakeBoeblingen()` as our backend, which has 20 qubits. However, this DAG does not use any quantum registers above q[3]. Feel free to define a different backend and see how the DAG differs.
#
# Now, lets check the results when we actually run the circuit:

# %%
results_BV_Lev0 = simulated_backend.run(transpiled_qc0).result()
# Out:
# 2022-06-27 12:47:18,014 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)

# %%
counts = results_BV_Lev0.get_counts()
plot_histogram(counts)
# optimization_level=0: just maps the circuit to the backend, with no explicit optimization 
# (except whatever optimizations the mapper does).

# %% [markdown]
# ### Some Optimization

# %%
# Define a simulated noisy backend
simulated_backend = FakeBoeblingen()

transpiled_qc1 = transpile(qc, simulated_backend, optimization_level=1)  # Some Optimization
print('Optimization Level 1')
print('Depth:', transpiled_qc1.depth())
print('Gate counts:', transpiled_qc1.count_ops())
transpiled_qc1.draw()
# Out:
# 2022-06-25 23:20:00,184 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00310 (ms)
#
# 2022-06-25 23:20:00,185 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03982 (ms)
#
# 2022-06-25 23:20:00,185 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01597 (ms)
#
# 2022-06-25 23:20:00,186 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: TrivialLayout - 0.04792 (ms)
#
# 2022-06-25 23:20:00,186 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Layout2qDistance - 0.11897 (ms)
#
# 2022-06-25 23:20:00,188 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 1.08314 (ms)
#
# 2022-06-25 23:20:00,188 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.10920 (ms)
#
# 2022-06-25 23:20:00,189 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.11301 (ms)
#
# 2022-06-25 23:20:00,189 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.37408 (ms)
#
# 2022-06-25 23:20:00,190 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.03529 (ms)
#
# 2022-06-25 23:20:00,190 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.10085 (ms)
#
# 2022-06-25 23:20:00,190 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.05317 (ms)
#
# 2022-06-25 23:20:00,191 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('id', 1), ('cx', 2), ('h', 1), ('measure', 1), ('barrier', 4), ('z', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:00,192 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.001s.
#
# 2022-06-25 23:20:00,193 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.001s.
#
# 2022-06-25 23:20:00,194 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:00,194 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 3.40986 (ms)
#
# 2022-06-25 23:20:00,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.02003 (ms)
#
# 2022-06-25 23:20:00,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02909 (ms)
#
# 2022-06-25 23:20:00,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:00,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:00,196 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00978 (ms)
#
# 2022-06-25 23:20:00,197 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 1.10412 (ms)
#
# 2022-06-25 23:20:00,197 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CXCancellation - 0.04411 (ms)
#
# 2022-06-25 23:20:00,198 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.14067 (ms)
#
# 2022-06-25 23:20:00,198 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02909 (ms)
#
# 2022-06-25 23:20:00,199 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:00,199 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:00,200 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:00,200 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:00,201 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.92308 (ms)
#
# 2022-06-25 23:20:00,201 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02718 (ms)
#
# 2022-06-25 23:20:00,201 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00787 (ms)
#
# 2022-06-25 23:20:00,202 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:00,202 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00572 (ms)
#
# 2022-06-25 23:20:00,203 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.70000 (ms)
#
# 2022-06-25 23:20:00,203 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CXCancellation - 0.03314 (ms)
#
# 2022-06-25 23:20:00,204 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.12422 (ms)
#
# 2022-06-25 23:20:00,204 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02480 (ms)
#
# 2022-06-25 23:20:00,204 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:00,205 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:00,205 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:00,205 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:00,205 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.17683 (ms)
#
# 2022-06-25 23:20:00,206 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02217 (ms)
#
# 2022-06-25 23:20:00,206 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00572 (ms)
#
# 2022-06-25 23:20:00,206 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:00,207 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00596 (ms)
#
# 2022-06-25 23:20:00,207 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00429 (ms)
#
# 2022-06-25 23:20:00,207 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 1466.16125 (ms)
# Optimization Level 1
# Depth: 5
# Gate counts: OrderedDict([('u2', 7), ('measure', 3), ('barrier', 2), ('cx', 2)])
#                   ┌─────────┐  ░            ░ ┌─────────┐   ┌─┐
#         q_1 -> 0 ─┤ U2(0,π) ├──░────────■───░─┤ U2(0,π) ├───┤M├───
#                  ┌┴─────────┴┐ ░ ┌───┐┌─┴─┐ ░ └─────────┘   └╥┘
#         q_3 -> 1 ┤ U2(-π,-π) ├─░─┤ X ├┤ X ├─░────────────────╫────
#                  └───────────┘ ░ └─┬─┘└───┘ ░                ║
#   ancilla_0 -> 2 ──────────────────┼─────────────────────────╫────
#                                    │                         ║
#   ancilla_1 -> 3 ──────────────────┼─────────────────────────╫────
#                                    │                         ║
#   ancilla_2 -> 4 ──────────────────┼─────────────────────────╫────
#                                    │                         ║
#   ancilla_3 -> 5 ──────────────────┼─────────────────────────╫────
#                   ┌─────────┐  ░   │        ░ ┌─────────┐┌─┐ ║
#         q_0 -> 6 ─┤ U2(0,π) ├──░───■────────░─┤ U2(0,π) ├┤M├─╫────
#                   └─────────┘  ░            ░ └─────────┘└╥┘ ║
#   ancilla_4 -> 7 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
#   ancilla_5 -> 8 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
#   ancilla_6 -> 9 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
#  ancilla_7 -> 10 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
#  ancilla_8 -> 11 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
#  ancilla_9 -> 12 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
# ancilla_10 -> 13 ─────────────────────────────────────────╫──╫────
#                                                           ║  ║
# ancilla_11 -> 14 ─────────────────────────────────────────╫──╫────
#                   ┌─────────┐  ░            ░ ┌─────────┐ ║  ║ ┌─┐
#        q_2 -> 15 ─┤ U2(0,π) ├──░────────────░─┤ U2(0,π) ├─╫──╫─┤M├
#                   └─────────┘  ░            ░ └─────────┘ ║  ║ └╥┘
# ancilla_12 -> 16 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_13 -> 17 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_14 -> 18 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_15 -> 19 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
#             c: 3/═════════════════════════════════════════╩══╩══╩═
#                                                           0  1  2

# %%
results_BV_Lev1 = simulated_backend.run(transpiled_qc1).result()
counts = results_BV_Lev1.get_counts()
plot_histogram(counts)
# optimization_level=1: maps the circuit, but also does light-weight optimizations by collapsing adjacent gates.
# Out:
# 2022-06-25 23:20:00,584 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.07391 (ms)

# %% [markdown]
# Here, we can see the correct string was identified with a higher probability than with no optimization.

# %%
# Draw DAG of the transpiled circuit that used optimization_level=1
dag = circuit_to_dag(transpiled_qc1)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:01,147 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:01,149 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:01,149 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:01,149 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGB size=1567x719 at 0x7FAB091A1C40>

# %% [markdown]
# We can visually see that the DAG is much shallower with this setting, and there are far fewer CX gates.

# %% [markdown]
# ### More Optimization

# %%
# Define a simulated noisy backend
simulated_backend = FakeBoeblingen()

transpiled_qc2 = transpile(qc, simulated_backend, optimization_level=2)  # More Optimization
print('Optimization Level 2')
print('Depth:', transpiled_qc2.depth())
print('Gate counts:', transpiled_qc2.count_ops())
transpiled_qc2.draw()
# Out:
# 2022-06-25 23:20:02,679 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00215 (ms)
#
# 2022-06-25 23:20:02,679 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03600 (ms)
#
# 2022-06-25 23:20:02,680 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01502 (ms)
#
# 2022-06-25 23:20:02,681 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 0.93317 (ms)
#
# 2022-06-25 23:20:02,681 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.09489 (ms)
#
# 2022-06-25 23:20:02,682 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.09990 (ms)
#
# 2022-06-25 23:20:02,682 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.33593 (ms)
#
# 2022-06-25 23:20:02,683 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.12589 (ms)
#
# 2022-06-25 23:20:02,683 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.08225 (ms)
#
# 2022-06-25 23:20:02,683 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.05507 (ms)
#
# 2022-06-25 23:20:02,684 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('id', 1), ('cx', 2), ('h', 1), ('measure', 1), ('barrier', 4), ('z', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:02,685 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.001s.
#
# 2022-06-25 23:20:02,686 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.001s.
#
# 2022-06-25 23:20:02,686 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:02,687 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 3.03006 (ms)
#
# 2022-06-25 23:20:02,687 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.02289 (ms)
#
# 2022-06-25 23:20:02,687 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02813 (ms)
#
# 2022-06-25 23:20:02,687 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:02,688 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.01001 (ms)
#
# 2022-06-25 23:20:02,688 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00525 (ms)
#
# 2022-06-25 23:20:02,689 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 1.03021 (ms)
#
# 2022-06-25 23:20:02,691 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.75293 (ms)
#
# 2022-06-25 23:20:02,691 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.05627 (ms)
#
# 2022-06-25 23:20:02,691 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.08988 (ms)
#
# 2022-06-25 23:20:02,691 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02384 (ms)
#
# 2022-06-25 23:20:02,692 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:02,692 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:02,693 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:02,693 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:02,694 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.84011 (ms)
#
# 2022-06-25 23:20:02,694 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.04196 (ms)
#
# 2022-06-25 23:20:02,694 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00906 (ms)
#
# 2022-06-25 23:20:02,695 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00811 (ms)
#
# 2022-06-25 23:20:02,695 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00477 (ms)
#
# 2022-06-25 23:20:02,696 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.72217 (ms)
#
# 2022-06-25 23:20:02,696 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.32187 (ms)
#
# 2022-06-25 23:20:02,697 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.06080 (ms)
#
# 2022-06-25 23:20:02,697 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.11492 (ms)
#
# 2022-06-25 23:20:02,698 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.04196 (ms)
#
# 2022-06-25 23:20:02,698 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:02,698 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:02,699 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:02,699 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:02,700 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.71018 (ms)
#
# 2022-06-25 23:20:02,700 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.03219 (ms)
#
# 2022-06-25 23:20:02,700 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00620 (ms)
#
# 2022-06-25 23:20:02,700 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00882 (ms)
#
# 2022-06-25 23:20:02,701 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00596 (ms)
#
# 2022-06-25 23:20:02,701 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00525 (ms)
#
# 2022-06-25 23:20:02,701 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 1482.50985 (ms)
# Optimization Level 2
# Depth: 5
# Gate counts: OrderedDict([('u2', 7), ('measure', 3), ('barrier', 2), ('cx', 2)])
#
#   ancilla_0 -> 0 ─────────────────────────────────────────────────
#
#   ancilla_1 -> 1 ─────────────────────────────────────────────────
#
#   ancilla_2 -> 2 ─────────────────────────────────────────────────
#
#   ancilla_3 -> 3 ─────────────────────────────────────────────────
#
#   ancilla_4 -> 4 ─────────────────────────────────────────────────
#
#   ancilla_5 -> 5 ─────────────────────────────────────────────────
#
#   ancilla_6 -> 6 ─────────────────────────────────────────────────
#
#   ancilla_7 -> 7 ─────────────────────────────────────────────────
#
#   ancilla_8 -> 8 ─────────────────────────────────────────────────
#
#   ancilla_9 -> 9 ─────────────────────────────────────────────────
#
# ancilla_10 -> 10 ─────────────────────────────────────────────────
#
# ancilla_11 -> 11 ─────────────────────────────────────────────────
#                   ┌─────────┐  ░            ░ ┌─────────┐┌─┐
#        q_0 -> 12 ─┤ U2(0,π) ├──░───■────────░─┤ U2(0,π) ├┤M├──────
#                  ┌┴─────────┴┐ ░ ┌─┴─┐┌───┐ ░ └─────────┘└╥┘
#        q_3 -> 13 ┤ U2(-π,-π) ├─░─┤ X ├┤ X ├─░─────────────╫───────
#                  └┬─────────┬┘ ░ └───┘└─┬─┘ ░ ┌─────────┐ ║ ┌─┐
#        q_1 -> 14 ─┤ U2(0,π) ├──░────────■───░─┤ U2(0,π) ├─╫─┤M├───
#                   ├─────────┤  ░            ░ ├─────────┤ ║ └╥┘┌─┐
#        q_2 -> 15 ─┤ U2(0,π) ├──░────────────░─┤ U2(0,π) ├─╫──╫─┤M├
#                   └─────────┘  ░            ░ └─────────┘ ║  ║ └╥┘
# ancilla_12 -> 16 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_13 -> 17 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_14 -> 18 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_15 -> 19 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
#             c: 3/═════════════════════════════════════════╩══╩══╩═
#                                                           0  1  2

# %%
results_BV_Lev2 = simulated_backend.run(transpiled_qc2).result()
counts = results_BV_Lev2.get_counts()
plot_histogram(counts)
# optimization_level=2: medium-weight optimization, including a noise-adaptive layout 
# and a gate-cancellation procedure based on gate commutation relationships.
# Out:
# 2022-06-25 23:20:03,065 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.09489 (ms)

# %%
# Draw DAG of the transpiled circuit that used optimization_level=2
dag = circuit_to_dag(transpiled_qc2)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:03,764 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:03,765 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:03,765 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:03,766 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGBA size=1519x719 at 0x7FAB091554C0>

# %% [markdown]
# Because this isn't such a complicated algorithm, there isn't all that much the transpiler can do. While the entire structure of the DAG changed between `optimization_level = 0` and `1`, it stays mostly the same here. However, the qubits which were chosen changed - note here its 3, 4, 8, and 15. This could be an optimization choice due to connectivity constraints.

# %% [markdown]
# ### Max Optimization

# %%
# Define a simulated noisy backend
simulated_backend = FakeBoeblingen()

transpiled_qc3 = transpile(qc, simulated_backend, optimization_level=3)  # MAXIMUM Optimization!!!
print('Optimization Level 3')
print('Depth:', transpiled_qc3.depth())
print('Gate counts:', transpiled_qc3.count_ops())
transpiled_qc3.draw()
# Out:
# 2022-06-25 23:20:05,329 --- qiskit.quantum_info.synthesis.two_qubit_decompose --- DEBUG: Requested fidelity: None calculated fidelity: 1.0 actual fidelity 1.0
#
# 2022-06-25 23:20:05,330 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03195 (ms)
#
# 2022-06-25 23:20:05,330 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01407 (ms)
#
# 2022-06-25 23:20:05,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.01216 (ms)
#
# 2022-06-25 23:20:05,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: OptimizeSwapBeforeMeasure - 0.00715 (ms)
#
# 2022-06-25 23:20:05,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveDiagonalGatesBeforeMeasure - 0.02193 (ms)
#
# 2022-06-25 23:20:05,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00310 (ms)
#
# 2022-06-25 23:20:05,333 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 0.91815 (ms)
#
# 2022-06-25 23:20:05,333 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.08702 (ms)
#
# 2022-06-25 23:20:05,333 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.10180 (ms)
#
# 2022-06-25 23:20:05,334 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.36502 (ms)
#
# 2022-06-25 23:20:05,334 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.11873 (ms)
#
# 2022-06-25 23:20:05,335 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.08297 (ms)
#
# 2022-06-25 23:20:05,335 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.04888 (ms)
#
# 2022-06-25 23:20:05,335 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('id', 1), ('cx', 2), ('h', 1), ('measure', 1), ('barrier', 4), ('z', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:05,336 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.001s.
#
# 2022-06-25 23:20:05,337 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.001s.
#
# 2022-06-25 23:20:05,338 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:05,338 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 2.62403 (ms)
#
# 2022-06-25 23:20:05,338 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.01407 (ms)
#
# 2022-06-25 23:20:05,338 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02503 (ms)
#
# 2022-06-25 23:20:05,339 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00811 (ms)
#
# 2022-06-25 23:20:05,339 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:05,340 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.01001 (ms)
#
# 2022-06-25 23:20:05,340 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.06890 (ms)
#
# 2022-06-25 23:20:05,342 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 1.59478 (ms)
#
# 2022-06-25 23:20:05,342 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.09298 (ms)
#
# 2022-06-25 23:20:05,343 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.80299 (ms)
#
# 2022-06-25 23:20:05,344 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.58794 (ms)
#
# 2022-06-25 23:20:05,345 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.05484 (ms)
#
# 2022-06-25 23:20:05,345 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.08106 (ms)
#
# 2022-06-25 23:20:05,345 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02313 (ms)
#
# 2022-06-25 23:20:05,345 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:05,346 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:05,346 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:05,347 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:05,347 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.80387 (ms)
#
# 2022-06-25 23:20:05,348 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02480 (ms)
#
# 2022-06-25 23:20:05,348 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:05,348 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00715 (ms)
#
# 2022-06-25 23:20:05,348 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00882 (ms)
#
# 2022-06-25 23:20:05,349 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.07701 (ms)
#
# 2022-06-25 23:20:05,351 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 1.62101 (ms)
#
# 2022-06-25 23:20:05,352 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.11802 (ms)
#
# 2022-06-25 23:20:05,353 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.57602 (ms)
#
# 2022-06-25 23:20:05,353 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.30613 (ms)
#
# 2022-06-25 23:20:05,353 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.05198 (ms)
#
# 2022-06-25 23:20:05,354 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.09799 (ms)
#
# 2022-06-25 23:20:05,354 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02694 (ms)
#
# 2022-06-25 23:20:05,354 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('barrier', 4), ('cx', 2), ('u2', 1)} to target basis {'reset', 'u2', 'cx', 'delay', 'u1', 'barrier', 'id', 'u3', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:05,355 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:05,355 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:05,355 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:05,356 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.36805 (ms)
#
# 2022-06-25 23:20:05,356 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02313 (ms)
#
# 2022-06-25 23:20:05,356 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00787 (ms)
#
# 2022-06-25 23:20:05,357 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:05,357 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:05,357 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00405 (ms)
#
# 2022-06-25 23:20:05,358 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 1510.36501 (ms)
# Optimization Level 3
# Depth: 5
# Gate counts: OrderedDict([('u2', 7), ('measure', 3), ('barrier', 2), ('cx', 2)])
#
#   ancilla_0 -> 0 ─────────────────────────────────────────────────
#
#   ancilla_1 -> 1 ─────────────────────────────────────────────────
#
#   ancilla_2 -> 2 ─────────────────────────────────────────────────
#
#   ancilla_3 -> 3 ─────────────────────────────────────────────────
#
#   ancilla_4 -> 4 ─────────────────────────────────────────────────
#
#   ancilla_5 -> 5 ─────────────────────────────────────────────────
#
#   ancilla_6 -> 6 ─────────────────────────────────────────────────
#
#   ancilla_7 -> 7 ─────────────────────────────────────────────────
#
#   ancilla_8 -> 8 ─────────────────────────────────────────────────
#
#   ancilla_9 -> 9 ─────────────────────────────────────────────────
#
# ancilla_10 -> 10 ─────────────────────────────────────────────────
#                  ┌───────────┐ ░ ┌───┐┌───┐ ░
#        q_3 -> 11 ┤ U2(-π,-π) ├─░─┤ X ├┤ X ├─░─────────────────────
#                  └┬─────────┬┘ ░ └─┬─┘└─┬─┘ ░ ┌─────────┐┌─┐
#        q_0 -> 12 ─┤ U2(0,π) ├──░───■────┼───░─┤ U2(0,π) ├┤M├──────
#                   └─────────┘  ░        │   ░ └─────────┘└╥┘
# ancilla_11 -> 13 ───────────────────────┼─────────────────╫───────
#                                         │                 ║
# ancilla_12 -> 14 ───────────────────────┼─────────────────╫───────
#                   ┌─────────┐  ░        │   ░ ┌─────────┐ ║    ┌─┐
#        q_2 -> 15 ─┤ U2(0,π) ├──░────────┼───░─┤ U2(0,π) ├─╫────┤M├
#                   ├─────────┤  ░        │   ░ ├─────────┤ ║ ┌─┐└╥┘
#        q_1 -> 16 ─┤ U2(0,π) ├──░────────■───░─┤ U2(0,π) ├─╫─┤M├─╫─
#                   └─────────┘  ░            ░ └─────────┘ ║ └╥┘ ║
# ancilla_13 -> 17 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_14 -> 18 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
# ancilla_15 -> 19 ─────────────────────────────────────────╫──╫──╫─
#                                                           ║  ║  ║
#             c: 3/═════════════════════════════════════════╩══╩══╩═
#                                                           0  1  2

# %%
results_BV_Lev3 = simulated_backend.run(transpiled_qc3).result()
counts = results_BV_Lev3.get_counts()
plot_histogram(counts)
# optimization_level=3: heavy-weight optimization, which in addition 
# to previous steps, does resynthesis of two-qubit blocks of gates in the circuit.
# Out:
# 2022-06-25 23:20:05,730 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.08821 (ms)

# %%
# Draw DAG of the transpiled circuit that used optimization_level=3
dag = circuit_to_dag(transpiled_qc3)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:06,345 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:06,347 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:06,347 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:06,347 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGBA size=1519x719 at 0x7FAB093042E0>

# %% [markdown]
# As you can see, this DAG of the transpiled circuit is reduced when using higher optimization levels. Furthermore, q[0] through q[3] contains less nodes than previous DAGs which means fewer operations, and a more efficient, less noisy quantum circuit :)

# %% [markdown]
# # Example 2: Trotterization
# ### What is Trotterization?
# Please look [here](https://vtomole.com/blog/2019/04/07/trotter) for a thorough explanation
#
# ### Why is Trotterization important?
# It is widely used to simulate non-commuting Hamiltonians on quantum computers.
#
# ### Why did we choose Trotterization as an example for the quantum compilation process?
# Trotterization has already been rigorously analyzed and is not too complicated to show its corresponding quantum circuit. Therefore, it serves as a simple, but important example. Rather than focus on the Trotterization algorithm itself (which has already been rigorously analyzed), we will focus on optimizing a Trotterization quantum circuit using the Qiskit transpilation process.
#
# ### Trotterization Circuit for Hamiltonian, $\mathbf{H} = \mathbf{Z} \otimes \mathbf{Z} \otimes \mathbf{Z} \otimes \mathbf{Z}$

# %%
# Import all functions
import numpy as np
import scipy as sp
from qiskit import Aer
from qiskit.opflow import PauliTrotterEvolution, StateFn, PauliExpectation
from qiskit.opflow import CircuitSampler, PauliOp
from qiskit.opflow import I, X, Y, Z, Zero, One, Plus, Minus
from qiskit.circuit import Parameter

# %%
hamiltonian = (Z^Z^Z^Z)
evo_time = Parameter('t')
evolution_op = (evo_time*hamiltonian).exp_i()
num_time_slices = 1
trotterized_op = PauliTrotterEvolution(
                    trotter_mode='trotter',
                    reps=num_time_slices).convert(evolution_op)
trot_op_circ = trotterized_op.to_circuit()
trot_op_circ_decomp = trot_op_circ.decompose()
trot_op_circ_decomp.draw()
# Out:
#                ┌───┐┌───────────┐┌───┐
# q_0: ──────────┤ X ├┤ Rz(2.0*t) ├┤ X ├──────────
#           ┌───┐└─┬─┘└───────────┘└─┬─┘┌───┐
# q_1: ─────┤ X ├──■─────────────────■──┤ X ├─────
#      ┌───┐└─┬─┘                       └─┬─┘┌───┐
# q_2: ┤ X ├──■───────────────────────────■──┤ X ├
#      └─┬─┘                                 └─┬─┘
# q_3: ──■─────────────────────────────────────■──

# %% [markdown]
# ### Choice of Backend
# Here we will be using the `FakeAthens()` backend and print out its basic information.
# For more information of the backend please visit:
# 1) [Backend_Resource1](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendConfiguration.html#qiskit.providers.models.BackendConfiguration)
#
# 2) [Backend_Resource2](https://qiskit.org/documentation/tutorials/circuits_advanced/08_gathering_system_information.html)

# %%
from qiskit.test.mock import FakeAthens

# Define a simulated noisy backend
simulated_backend = FakeAthens()


# Print out basic features of this backend. Note, I am using a function found in Backend_Resource2
config = simulated_backend.configuration()
print("This backend is called {0}, and is on version {1}. \nIt has {2} qubit{3}. \nIt "
      "{4} OpenPulse programs. \nThe basis gates supported on this device are {5}."
      "".format(config.backend_name,
                config.backend_version,
                config.n_qubits,
                '' if config.n_qubits == 1 else 's',
                'supports' if config.open_pulse else 'does not support',
                config.basis_gates))
# Out:
# This backend is called fake_athens, and is on version 1.3.13.
# It has 5 qubits.
# It supports OpenPulse programs.
# The basis gates supported on this device are ['id', 'rz', 'sx', 'x', 'cx', 'reset'].

# %% [markdown]
# ### Optimization_level=0

# %%
#Optimization_Level=0
transpiled_qc0 = transpile(trot_op_circ_decomp, simulated_backend, optimization_level=0)  # No Optimization
print('Optimization Level 0')
print('Depth:', transpiled_qc0.depth())
print('Gate counts:', transpiled_qc0.count_ops())
transpiled_qc0.draw()
# Out:
# 2022-06-25 23:20:07,327 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00310 (ms)
#
# 2022-06-25 23:20:07,327 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03195 (ms)
#
# 2022-06-25 23:20:07,327 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.00787 (ms)
#
# 2022-06-25 23:20:07,328 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: TrivialLayout - 0.04411 (ms)
#
# 2022-06-25 23:20:07,328 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.04077 (ms)
#
# 2022-06-25 23:20:07,328 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.02408 (ms)
#
# 2022-06-25 23:20:07,329 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.16117 (ms)
#
# 2022-06-25 23:20:07,329 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.05889 (ms)
#
# 2022-06-25 23:20:07,329 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03672 (ms)
#
# 2022-06-25 23:20:07,329 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02623 (ms)
#
# 2022-06-25 23:20:07,330 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:07,330 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:07,330 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:07,331 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:07,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.31392 (ms)
#
# 2022-06-25 23:20:07,331 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00405 (ms)
#
# 2022-06-25 23:20:07,331 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 320.15014 (ms)
# Optimization Level 0
# Depth: 7
# Gate counts: OrderedDict([('cx', 6), ('rz', 1)])
#                          ┌───┐┌───────────┐┌───┐
#       q_0 -> 0 ──────────┤ X ├┤ Rz(2.0*t) ├┤ X ├──────────
#                     ┌───┐└─┬─┘└───────────┘└─┬─┘┌───┐
#       q_1 -> 1 ─────┤ X ├──■─────────────────■──┤ X ├─────
#                ┌───┐└─┬─┘                       └─┬─┘┌───┐
#       q_2 -> 2 ┤ X ├──■───────────────────────────■──┤ X ├
#                └─┬─┘                                 └─┬─┘
#       q_3 -> 3 ──■─────────────────────────────────────■──
#
# ancilla_0 -> 4 ───────────────────────────────────────────

# %%
# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(transpiled_qc0)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:07,587 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:07,589 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:07,589 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:07,589 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGB size=420x719 at 0x7FAB009A4340>

# %% [markdown]
# ### Optimization_level=1

# %%
#Optimization_Level=0
transpiled_qc1 = transpile(trot_op_circ_decomp, simulated_backend, optimization_level=1)  
print('Optimization Level 1')
print('Depth:', transpiled_qc1.depth())
print('Gate counts:', transpiled_qc1.count_ops())
transpiled_qc1.draw()
# Out:
# 2022-06-25 23:20:07,614 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00310 (ms)
#
# 2022-06-25 23:20:07,615 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.05078 (ms)
#
# 2022-06-25 23:20:07,615 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01478 (ms)
#
# 2022-06-25 23:20:07,615 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: TrivialLayout - 0.05412 (ms)
#
# 2022-06-25 23:20:07,616 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Layout2qDistance - 0.07510 (ms)
#
# 2022-06-25 23:20:07,616 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.04721 (ms)
#
# 2022-06-25 23:20:07,617 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.05102 (ms)
#
# 2022-06-25 23:20:07,617 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.24605 (ms)
#
# 2022-06-25 23:20:07,617 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.04292 (ms)
#
# 2022-06-25 23:20:07,618 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.06604 (ms)
#
# 2022-06-25 23:20:07,618 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.03481 (ms)
#
# 2022-06-25 23:20:07,618 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:07,619 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:07,619 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:07,620 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:07,620 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.57428 (ms)
#
# 2022-06-25 23:20:07,620 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.01168 (ms)
#
# 2022-06-25 23:20:07,621 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.03123 (ms)
#
# 2022-06-25 23:20:07,621 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00787 (ms)
#
# 2022-06-25 23:20:07,621 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00811 (ms)
#
# 2022-06-25 23:20:07,621 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00381 (ms)
#
# 2022-06-25 23:20:07,622 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.03719 (ms)
#
# 2022-06-25 23:20:07,622 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CXCancellation - 0.03099 (ms)
#
# 2022-06-25 23:20:07,622 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.04816 (ms)
#
# 2022-06-25 23:20:07,623 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02909 (ms)
#
# 2022-06-25 23:20:07,624 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:07,624 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:07,625 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:07,625 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:07,625 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.91069 (ms)
#
# 2022-06-25 23:20:07,626 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02789 (ms)
#
# 2022-06-25 23:20:07,626 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:07,627 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00596 (ms)
#
# 2022-06-25 23:20:07,627 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00620 (ms)
#
# 2022-06-25 23:20:07,627 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00477 (ms)
#
# 2022-06-25 23:20:07,628 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 17.04073 (ms)
# Optimization Level 1
# Depth: 7
# Gate counts: OrderedDict([('cx', 6), ('rz', 1)])
#                          ┌───┐┌───────────┐┌───┐
#       q_0 -> 0 ──────────┤ X ├┤ Rz(2.0*t) ├┤ X ├──────────
#                     ┌───┐└─┬─┘└───────────┘└─┬─┘┌───┐
#       q_1 -> 1 ─────┤ X ├──■─────────────────■──┤ X ├─────
#                ┌───┐└─┬─┘                       └─┬─┘┌───┐
#       q_2 -> 2 ┤ X ├──■───────────────────────────■──┤ X ├
#                └─┬─┘                                 └─┬─┘
#       q_3 -> 3 ──■─────────────────────────────────────■──
#
# ancilla_0 -> 4 ───────────────────────────────────────────

# %%
# Draw DAG of the transpiled circuit that used optimization_level=1
dag = circuit_to_dag(transpiled_qc1)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:07,884 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:07,885 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:07,885 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:07,885 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGB size=420x719 at 0x7FAAF902FE20>

# %% [markdown]
# ### Optimization_level=2

# %%
#Optimization_Level=2
transpiled_qc2 = transpile(trot_op_circ_decomp, simulated_backend, optimization_level=2) 
print('Optimization Level 2')
print('Depth:', transpiled_qc2.depth())
print('Gate counts:', transpiled_qc2.count_ops())
transpiled_qc2.draw()
# Out:
# 2022-06-25 23:20:07,909 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00310 (ms)
#
# 2022-06-25 23:20:07,911 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.05078 (ms)
#
# 2022-06-25 23:20:07,911 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01383 (ms)
#
# 2022-06-25 23:20:07,912 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 0.54026 (ms)
#
# 2022-06-25 23:20:07,912 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.05674 (ms)
#
# 2022-06-25 23:20:07,913 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.03219 (ms)
#
# 2022-06-25 23:20:07,913 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.22078 (ms)
#
# 2022-06-25 23:20:07,914 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.06986 (ms)
#
# 2022-06-25 23:20:07,914 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.06723 (ms)
#
# 2022-06-25 23:20:07,914 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02718 (ms)
#
# 2022-06-25 23:20:07,915 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:07,915 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:07,915 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:07,916 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:07,916 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.45793 (ms)
#
# 2022-06-25 23:20:07,917 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.02980 (ms)
#
# 2022-06-25 23:20:07,917 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.06509 (ms)
#
# 2022-06-25 23:20:07,918 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.01979 (ms)
#
# 2022-06-25 23:20:07,918 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00787 (ms)
#
# 2022-06-25 23:20:07,918 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:07,919 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.04697 (ms)
#
# 2022-06-25 23:20:07,921 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 1.86491 (ms)
#
# 2022-06-25 23:20:07,921 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.05889 (ms)
#
# 2022-06-25 23:20:07,922 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.05484 (ms)
#
# 2022-06-25 23:20:07,922 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02313 (ms)
#
# 2022-06-25 23:20:07,922 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:07,923 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:07,923 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:07,924 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:07,924 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.41907 (ms)
#
# 2022-06-25 23:20:07,924 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.02313 (ms)
#
# 2022-06-25 23:20:07,924 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:07,925 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00501 (ms)
#
# 2022-06-25 23:20:07,925 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00596 (ms)
#
# 2022-06-25 23:20:07,925 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00691 (ms)
#
# 2022-06-25 23:20:07,926 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 19.70816 (ms)
# Optimization Level 2
# Depth: 7
# Gate counts: OrderedDict([('cx', 6), ('rz', 1)])
#
#       q_3 -> 0 ──■─────────────────────────────────────■──
#                ┌─┴─┐                                 ┌─┴─┐
#       q_2 -> 1 ┤ X ├──■───────────────────────────■──┤ X ├
#                └───┘┌─┴─┐                       ┌─┴─┐└───┘
#       q_1 -> 2 ─────┤ X ├──■─────────────────■──┤ X ├─────
#                     └───┘┌─┴─┐┌───────────┐┌─┴─┐└───┘
#       q_0 -> 3 ──────────┤ X ├┤ Rz(2.0*t) ├┤ X ├──────────
#                          └───┘└───────────┘└───┘
# ancilla_0 -> 4 ───────────────────────────────────────────

# %%
# Draw DAG of the transpiled circuit that used optimization_level=1
dag = circuit_to_dag(transpiled_qc2)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:08,183 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:08,184 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:08,185 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:08,185 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGB size=309x719 at 0x7FAB0089E550>

# %% [markdown]
# ### Optimization_level=3

# %%
#Optimization_Level=2
transpiled_qc3 = transpile(trot_op_circ_decomp, simulated_backend, optimization_level=3) 
print('Optimization Level 3')
print('Depth:', transpiled_qc3.depth())
print('Gate counts:', transpiled_qc3.count_ops())
transpiled_qc3.draw()
# Out:
# 2022-06-25 23:20:08,212 --- qiskit.quantum_info.synthesis.two_qubit_decompose --- DEBUG: Requested fidelity: None calculated fidelity: 1.0 actual fidelity 1.0
#
# 2022-06-25 23:20:08,215 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.04506 (ms)
#
# 2022-06-25 23:20:08,215 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.01311 (ms)
#
# 2022-06-25 23:20:08,215 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.01001 (ms)
#
# 2022-06-25 23:20:08,216 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: OptimizeSwapBeforeMeasure - 0.01097 (ms)
#
# 2022-06-25 23:20:08,216 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveDiagonalGatesBeforeMeasure - 0.01597 (ms)
#
# 2022-06-25 23:20:08,216 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00381 (ms)
#
# 2022-06-25 23:20:08,217 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 0.53191 (ms)
#
# 2022-06-25 23:20:08,217 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.06199 (ms)
#
# 2022-06-25 23:20:08,218 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.03219 (ms)
#
# 2022-06-25 23:20:08,218 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 0.22292 (ms)
#
# 2022-06-25 23:20:08,219 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.08082 (ms)
#
# 2022-06-25 23:20:08,219 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.08011 (ms)
#
# 2022-06-25 23:20:08,220 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.03099 (ms)
#
# 2022-06-25 23:20:08,220 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:08,220 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:08,221 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:08,222 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:08,222 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 2.09308 (ms)
#
# 2022-06-25 23:20:08,222 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.00715 (ms)
#
# 2022-06-25 23:20:08,223 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.04196 (ms)
#
# 2022-06-25 23:20:08,223 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.01884 (ms)
#
# 2022-06-25 23:20:08,224 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00882 (ms)
#
# 2022-06-25 23:20:08,224 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00906 (ms)
#
# 2022-06-25 23:20:08,224 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.12207 (ms)
#
# 2022-06-25 23:20:08,229 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 3.93081 (ms)
#
# 2022-06-25 23:20:08,229 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.06509 (ms)
#
# 2022-06-25 23:20:08,229 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.02003 (ms)
#
# 2022-06-25 23:20:08,231 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.94080 (ms)
#
# 2022-06-25 23:20:08,231 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.04721 (ms)
#
# 2022-06-25 23:20:08,231 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.03791 (ms)
#
# 2022-06-25 23:20:08,231 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.02098 (ms)
#
# 2022-06-25 23:20:08,232 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rz', 1), ('cx', 2)} to target basis {'reset', 'sx', 'cx', 'x', 'delay', 'rz', 'barrier', 'id', 'snapshot', 'measure'}.
#
# 2022-06-25 23:20:08,232 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-06-25 23:20:08,233 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-06-25 23:20:08,233 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-06-25 23:20:08,233 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.45578 (ms)
#
# 2022-06-25 23:20:08,234 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.03004 (ms)
#
# 2022-06-25 23:20:08,234 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00811 (ms)
#
# 2022-06-25 23:20:08,234 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00787 (ms)
#
# 2022-06-25 23:20:08,235 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00691 (ms)
#
# 2022-06-25 23:20:08,235 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00381 (ms)
#
# 2022-06-25 23:20:08,235 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 31.55899 (ms)
# Optimization Level 3
# Depth: 7
# Gate counts: OrderedDict([('cx', 6), ('rz', 1)])
#
#       q_3 -> 0 ──■─────────────────────────────────────■──
#                ┌─┴─┐                                 ┌─┴─┐
#       q_2 -> 1 ┤ X ├──■───────────────────────────■──┤ X ├
#                └───┘┌─┴─┐                       ┌─┴─┐└───┘
#       q_1 -> 2 ─────┤ X ├──■─────────────────■──┤ X ├─────
#                     └───┘┌─┴─┐┌───────────┐┌─┴─┐└───┘
#       q_0 -> 3 ──────────┤ X ├┤ Rz(2.0*t) ├┤ X ├──────────
#                          └───┘└───────────┘└───┘
# ancilla_0 -> 4 ───────────────────────────────────────────

# %%
# Draw DAG of the transpiled circuit that used optimization_level=1
dag = circuit_to_dag(transpiled_qc3)
dag_drawer(dag)
# Out:
# 2022-06-25 23:20:08,614 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IHDR' 16 13
#
# 2022-06-25 23:20:08,615 --- PIL.PngImagePlugin --- DEBUG: STREAM b'bKGD' 41 6
#
# 2022-06-25 23:20:08,616 --- PIL.PngImagePlugin --- DEBUG: b'bKGD' 41 6 (unknown)
#
# 2022-06-25 23:20:08,616 --- PIL.PngImagePlugin --- DEBUG: STREAM b'IDAT' 59 8192
# <PIL.Image.Image image mode=RGB size=309x719 at 0x7FAAF9B680D0>
