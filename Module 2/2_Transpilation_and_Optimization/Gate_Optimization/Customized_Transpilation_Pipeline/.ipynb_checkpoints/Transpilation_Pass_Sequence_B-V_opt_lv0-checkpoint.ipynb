# %% [markdown]
# # Making our own Transpilation Process using the PassManager.
# Up to now we've shown how to use predefined transpilation processes by setting the `optimization_level` parameter to a value from `0 to 3`. However, to create our own quantum compiler toolchain, we must be able to create a customized transpilation process. This is accomplished by using a **sequence of Transpiler passes** which are managed by the **PassManager**. These passes act directly on the Directed Acyclic Graph (DAG) representation of the quantum circuit. There are two types of passes we can
# use, which are:
#
# 1) **Analysis Pass**: Can read and save specific DAG properties (save the information of a particular node in the DAG).
#
# 2) **Transformation Pass**: Can Modify the DAG (adding gates, etc.), but has read-only access to the circuit properties.
#
# [HERE](https://qiskit.org/documentation/apidoc/transpiler_passes.html) you can see a list of the defined transpiler passes used in Qiskit. They are also printed out in the following cell for convenience.

# %%
from qiskit.transpiler import passes

[transpiler_pass for transpiler_pass in dir(passes) if transpiler_pass[0].isupper()]
# Out:
# ['ALAPSchedule',
#  'ASAPSchedule',
#  'AlignMeasures',
#  'ApplyLayout',
#  'BIPMapping',
#  'BarrierBeforeFinalMeasurements',
#  'BasicSwap',
#  'BasisTranslator',
#  'CSPLayout',
#  'CXCancellation',
#  'CXDirection',
#  'CheckCXDirection',
#  'CheckGateDirection',
#  'CheckMap',
#  'Collect1qRuns',
#  'Collect2qBlocks',
#  'CollectMultiQBlocks',
#  'CommutationAnalysis',
#  'CommutativeCancellation',
#  'ConsolidateBlocks',
#  'ContainsInstruction',
#  'CountOps',
#  'CountOpsLongestPath',
#  'CrosstalkAdaptiveSchedule',
#  'DAGFixedPoint',
#  'DAGLongestPath',
#  'Decompose',
#  'DenseLayout',
#  'Depth',
#  'DynamicalDecoupling',
#  'EchoRZXWeylDecomposition',
#  'EnlargeWithAncilla',
#  'Error',
#  'FixedPoint',
#  'FullAncillaAllocation',
#  'GateDirection',
#  'GatesInBasis',
#  'HoareOptimizer',
#  'InverseCancellation',
#  'Layout2qDistance',
#  'LayoutTransformation',
#  'LookaheadSwap',
#  'MergeAdjacentBarriers',
#  'NoiseAdaptiveLayout',
#  'NumTensorFactors',
#  'Optimize1qGates',
#  'Optimize1qGatesDecomposition',
#  'Optimize1qGatesSimpleCommutation',
#  'OptimizeSwapBeforeMeasure',
#  'PulseGates',
#  'RZXCalibrationBuilder',
#  'RZXCalibrationBuilderNoEcho',
#  'RemoveBarriers',
#  'RemoveDiagonalGatesBeforeMeasure',
#  'RemoveFinalMeasurements',
#  'RemoveResetInZeroState',
#  'ResourceEstimation',
#  'SabreLayout',
#  'SabreSwap',
#  'SetLayout',
#  'Size',
#  'StochasticSwap',
#  'TemplateOptimization',
#  'TimeUnitConversion',
#  'TrivialLayout',
#  'UnitarySynthesis',
#  'Unroll3qOrMore',
#  'UnrollCustomDefinitions',
#  'Unroller',
#  'VF2Layout',
#  'ValidatePulseGates',
#  'Width']

# %% [markdown]
# ## Customized Transpilation pipeline

# %% [markdown]
# ### Example 1: Simple Circuit
# **Step 0:** Lets define our backend and get some of its properties and see its qubit connectivity(i.e. **coupling_map**)

# %%
from qiskit import IBMQ
from qiskit.tools.jupyter import *
from qiskit.test.mock import FakeAthens
from qiskit.transpiler import CouplingMap

# Define a simulated noisy backend
simulated_backend = FakeAthens()



# Print out basic features of this backend. Note, I am using a function found in Backend_Resource2
config = simulated_backend.configuration()
print("This backend is called {0}, and is on version {1}. \nIt has {2} qubit{3}. \nIt "
      "{4} OpenPulse programs. \nThe basis gates supported on this device are {5}. \nCoupling Map: {6}\n"
      "".format(config.backend_name,
                config.backend_version,
                config.n_qubits,
                '' if config.n_qubits == 1 else 's',
                'supports' if config.open_pulse else 'does not support',
                config.basis_gates,
                config.coupling_map))

cm = CouplingMap(config.coupling_map)
cm.draw()
# Out:
# This backend is called fake_athens, and is on version 1.3.13.
# It has 5 qubits.
# It supports OpenPulse programs.
# The basis gates supported on this device are ['id', 'rz', 'sx', 'x', 'cx', 'reset'].
# Coupling Map: [[0, 1], [1, 0], [1, 2], [2, 1], [2, 3], [3, 2], [3, 4], [4, 3]]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=435x209 at 0x2778515AEB0>

# %% [markdown]
# **Step 1:** We begin with a basic circuit.

# %%
# For Passes
from qiskit import QuantumCircuit
from qiskit.compiler import transpile
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroller


# Define your circuit
circ = QuantumCircuit(2)
#circ.ccx(0, 1, 2)
circ.cz(0,1);
circ.draw(output='mpl')

# %% [markdown]
# Lets see what this circuit looks like as a DAG.

# %%
# For drawing DAG
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import circuit_to_dag
from qiskit.tools.visualization import dag_drawer

# Required software to visually see DAG
# !pip install pydot

dag = circuit_to_dag(circ)
dag_drawer(dag)
# Out:
# Requirement already satisfied: pydot in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (from pydot) (2.4.7)
# <PIL.Image.Image image mode=RGBA size=130x212 at 0x2778547C880>

# %% [markdown]
# **Step 2:** We expand the circuit into a chosen basis gate set.

# %%
# Create a customized transpilation pipeline.
pm = PassManager()

# Pass 1: Expand a quantum circuit into the chosen basis set.
unroll_pass = Unroller(['u1', 'u2', 'u3', 'cx'])
pm.append(unroll_pass)


new_circ = pm.run(circ)
new_circ.draw(output='mpl')

# %% [markdown]
# Now, lets see what this expanded circuit looks like as a DAG.

# %%
dag = circuit_to_dag(new_circ)
dag_drawer(dag)
# Out:
# <PIL.Image.Image image mode=RGBA size=136x381 at 0x277073888B0>

# %% [markdown]
# **Step 3:** Use additional passes on the expanded gate set.

# %%
# Pass n: Can append as many passes as you want.

# Lets print out list of passes we are currently using.
pm.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=141x228 at 0x277854FEB80>

# %%
new_circ = pm.run(circ)
new_circ.draw(output='mpl')

# %% [markdown]
# Finally, lets see what kind of DAG we have after applying multiple passes.

# %%
dag = circuit_to_dag(new_circ)
dag_drawer(dag)
# Out:
# <PIL.Image.Image image mode=RGBA size=136x381 at 0x277853AD9D0>

# %% [markdown]
# ## Example 2: Recreating the transpilation process for B-V circuit at optimization_level=0
# In this section we will learn which exact transpiler passes are used when setting `optimization_level=0` for `transpile()`. We will specifically go over transpiling the B-V circuit. Simply put, in this example we will recreate the same transpilation pipeline used when `optimization_level=0`and produce the same circuit using our own transpilation pipeline(which is based on the passes used in `optimization_level=0`). Here are the steps:
# 1. Define our backend, get its properties and visualize its qubit connectivity(i.e. **coupling_map**).
# 2. Use the Berstein-Vazirani circuit for a 3 bit hidden string s.
# 3. Set up a Logger to save all of the passes used for the transpilation pipeline of `optimization_level=0`
# 4. Transpile using `optimization_level=0`.
# 5. Read text file containing all transpiler passes, store transpiler passes into a Pass Manager object.
#
#
#
#
#
#
#
# ### Step 0: Lets define our backend, get its properties and visualize its qubit connectivity(i.e. **coupling_map**)
#
# Here we will be using the `FakeBoeblingen()` backend and print out its basic information.
# For more information of the backend please visit:
#
# 1) [Backend_Configuration_Information](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendConfiguration.html#qiskit.providers.models.BackendConfiguration)
#
# 2) [Backend_Properties_Information](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendProperties.html#qiskit.providers.models.BackendProperties)
#
# 3) [Backend_General_Information](https://qiskit.org/documentation/tutorials/circuits_advanced/08_gathering_system_information.html)

# %%
from qiskit import IBMQ
from qiskit.tools.jupyter import *
from qiskit.test.mock import FakeBoeblingen
from qiskit.transpiler import CouplingMap
import pprint
pp = pprint.PrettyPrinter(indent=4)


# Define a simulated noisy backend
simulated_backend = FakeBoeblingen()



# Print out basic features of this backend. Note, I am using a function found in Backend_General_Information
print("---------------------------------Backend Configuration---------------------------------")

config = simulated_backend.configuration()
#pp.pprint(config.to_dict())
print("This backend is called {0}, and is on version {1}. \nIt has {2} qubit{3}. \nIt "
      "{4} OpenPulse programs. \nThe basis gates supported on this device are {5}. \nCoupling Map: {6}\n"
      "".format(config.backend_name,
                config.backend_version,
                config.n_qubits,
                '' if config.n_qubits == 1 else 's',
                'supports' if config.open_pulse else 'does not support',
                config.basis_gates,
                config.coupling_map))
cm = CouplingMap(config.coupling_map)


print("---------------------------------Backend Properties---------------------------------")
# Print out information about the Properties of the backend.
properties = simulated_backend.properties()

pp.pprint(properties.to_dict())
# Out:
# ---------------------------------Configuration---------------------------------
# This backend is called fake_boeblingen, and is on version 1.2.9.
# It has 20 qubits.
# It supports OpenPulse programs.
# The basis gates supported on this device are ['id', 'u1', 'u2', 'u3', 'cx'].
# Coupling Map: [[0, 1], [1, 0], [1, 2], [1, 6], [2, 1], [2, 3], [3, 2], [3, 4], [3, 8], [4, 3], [5, 6], [5, 10], [6, 1], [6, 5], [6, 7], [7, 6], [7, 8], [7, 12], [8, 3], [8, 7], [8, 9], [9, 8], [9, 14], [10, 5], [10, 11], [11, 10], [11, 12], [11, 16], [12, 7], [12, 11], [12, 13], [13, 12], [13, 14], [13, 18], [14, 9], [14, 13], [15, 16], [16, 11], [16, 15], [16, 17], [17, 16], [17, 18], [18, 13], [18, 17], [18, 19], [19, 18]]
#
# ---------------------------------Properties---------------------------------
# {   'backend_name': 'ibmq_boeblingen',
#     'backend_version': '1.2.9',
#     'gates': [   {   'gate': 'id',
#                      'name': 'id0',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00023855765187208629},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [0]},
#                  {   'gate': 'id',
#                      'name': 'id1',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00031184241260348973},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [1]},
#                  {   'gate': 'id',
#                      'name': 'id2',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005399110585891418},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [2]},
#                  {   'gate': 'id',
#                      'name': 'id3',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00032460860123477756},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [3]},
#                  {   'gate': 'id',
#                      'name': 'id4',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00046067926001784333},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [4]},
#                  {   'gate': 'id',
#                      'name': 'id5',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006954152356710452},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [5]},
#                  {   'gate': 'id',
#                      'name': 'id6',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 28, 20, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0014430699420731748},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [6]},
#                  {   'gate': 'id',
#                      'name': 'id7',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005291345473375843},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [7]},
#                  {   'gate': 'id',
#                      'name': 'id8',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 28, 20, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0003812601426374729},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [8]},
#                  {   'gate': 'id',
#                      'name': 'id9',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0004900653901014868},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [9]},
#                  {   'gate': 'id',
#                      'name': 'id10',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006611577529736489},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [10]},
#                  {   'gate': 'id',
#                      'name': 'id11',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0007456548534376229},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [11]},
#                  {   'gate': 'id',
#                      'name': 'id12',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00035217657854891987},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [12]},
#                  {   'gate': 'id',
#                      'name': 'id13',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0007872376369094243},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [13]},
#                  {   'gate': 'id',
#                      'name': 'id14',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00041971114150360074},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [14]},
#                  {   'gate': 'id',
#                      'name': 'id15',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00024993672232147946},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [15]},
#                  {   'gate': 'id',
#                      'name': 'id16',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0004794413760867113},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [16]},
#                  {   'gate': 'id',
#                      'name': 'id17',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.000364458623454041},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [17]},
#                  {   'gate': 'id',
#                      'name': 'id18',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005356652918609618},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [18]},
#                  {   'gate': 'id',
#                      'name': 'id19',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0008151877833844501},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [19]},
#                  {   'gate': 'u1',
#                      'name': 'u10',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [0]},
#                  {   'gate': 'u1',
#                      'name': 'u11',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [1]},
#                  {   'gate': 'u1',
#                      'name': 'u12',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [2]},
#                  {   'gate': 'u1',
#                      'name': 'u13',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [3]},
#                  {   'gate': 'u1',
#                      'name': 'u14',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [4]},
#                  {   'gate': 'u1',
#                      'name': 'u15',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [5]},
#                  {   'gate': 'u1',
#                      'name': 'u16',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [6]},
#                  {   'gate': 'u1',
#                      'name': 'u17',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [7]},
#                  {   'gate': 'u1',
#                      'name': 'u18',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [8]},
#                  {   'gate': 'u1',
#                      'name': 'u19',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [9]},
#                  {   'gate': 'u1',
#                      'name': 'u110',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [10]},
#                  {   'gate': 'u1',
#                      'name': 'u111',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [11]},
#                  {   'gate': 'u1',
#                      'name': 'u112',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [12]},
#                  {   'gate': 'u1',
#                      'name': 'u113',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [13]},
#                  {   'gate': 'u1',
#                      'name': 'u114',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [14]},
#                  {   'gate': 'u1',
#                      'name': 'u115',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [15]},
#                  {   'gate': 'u1',
#                      'name': 'u116',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [16]},
#                  {   'gate': 'u1',
#                      'name': 'u117',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [17]},
#                  {   'gate': 'u1',
#                      'name': 'u118',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [18]},
#                  {   'gate': 'u1',
#                      'name': 'u119',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 0}],
#                      'qubits': [19]},
#                  {   'gate': 'u2',
#                      'name': 'u20',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00023855765187208629},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [0]},
#                  {   'gate': 'u2',
#                      'name': 'u21',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00031184241260348973},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [1]},
#                  {   'gate': 'u2',
#                      'name': 'u22',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005399110585891418},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [2]},
#                  {   'gate': 'u2',
#                      'name': 'u23',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00032460860123477756},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [3]},
#                  {   'gate': 'u2',
#                      'name': 'u24',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00046067926001784333},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [4]},
#                  {   'gate': 'u2',
#                      'name': 'u25',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006954152356710452},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [5]},
#                  {   'gate': 'u2',
#                      'name': 'u26',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 28, 20, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0014430699420731748},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [6]},
#                  {   'gate': 'u2',
#                      'name': 'u27',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005291345473375843},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [7]},
#                  {   'gate': 'u2',
#                      'name': 'u28',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 28, 20, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0003812601426374729},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [8]},
#                  {   'gate': 'u2',
#                      'name': 'u29',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0004900653901014868},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [9]},
#                  {   'gate': 'u2',
#                      'name': 'u210',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006611577529736489},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [10]},
#                  {   'gate': 'u2',
#                      'name': 'u211',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0007456548534376229},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [11]},
#                  {   'gate': 'u2',
#                      'name': 'u212',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00035217657854891987},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [12]},
#                  {   'gate': 'u2',
#                      'name': 'u213',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0007872376369094243},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [13]},
#                  {   'gate': 'u2',
#                      'name': 'u214',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00041971114150360074},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [14]},
#                  {   'gate': 'u2',
#                      'name': 'u215',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00024993672232147946},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [15]},
#                  {   'gate': 'u2',
#                      'name': 'u216',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0004794413760867113},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [16]},
#                  {   'gate': 'u2',
#                      'name': 'u217',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.000364458623454041},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [17]},
#                  {   'gate': 'u2',
#                      'name': 'u218',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0005356652918609618},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [18]},
#                  {   'gate': 'u2',
#                      'name': 'u219',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0008151877833844501},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                      'qubits': [19]},
#                  {   'gate': 'u3',
#                      'name': 'u30',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00047705839399092564},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 71.11111111111111}],
#                      'qubits': [0]},
#                  {   'gate': 'u3',
#                      'name': 'u31',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006235875795167489},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 71.11111111111111}],
#                      'qubits': [1]},
#                  {   'gate': 'u3',
#                      'name': 'u32',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0010795306132271865},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 71.11111111111111}],
#                      'qubits': [2]},
#                  {   'gate': 'u3',
#                      'name': 'u33',
#                      'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 21, 56, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.0006491118317254463},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
# ...
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 88.53720413389485},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 8, 4, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 137.78740219330246},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.736743283810309},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.3011550709795411},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.04059999999999997},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.056400000000000006},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0248},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 81.1462570174753},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 1, 7, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 118.32418173887328},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.635844021135856},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.3098712474110467},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.08289999999999997},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.10640000000000005},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0594},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 87.33999570313325},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 8, 4, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 109.52959884294162},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.555072960199026},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.3129302430716753},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.03279999999999994},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.04500000000000004},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0206},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 76.75614011581366},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 1, 7, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 153.18355924804465},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.582574341167944},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.3122909722059888},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.01319999999999999},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.020199999999999996},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0062},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 58.713228364178285},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 8, 4, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 50.929956134674214},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.755460952571235},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.30564278929575345},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.02190000000000003},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.031399999999999983},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0124},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 73.70973984241425},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 1, 7, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 78.09470281339988},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.589793416188125},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.3103398500148478},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.043099999999999916},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.07499999999999996},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.0112},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 96.45529628360418},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 8, 4, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 69.43440118923097},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 4.7518372606533585},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.30629705406648733},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.06940000000000002},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.0938},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.045},
#                       {   'date': datetime.datetime(2021, 2, 3, 4, 53, 14, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}],
#                   [   {   'date': datetime.datetime(2021, 2, 3, 5, 0, 2, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T1',
#                           'unit': 'us',
#                           'value': 98.44043441263481},
#                       {   'date': datetime.datetime(2021, 2, 3, 5, 1, 7, tzinfo=tzoffset(None, -18000)),
#                           'name': 'T2',
#                           'unit': 'us',
#                           'value': 95.03960659824975},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'frequency',
#                           'unit': 'GHz',
#                           'value': 5.035027745870665},
#                       {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                           'name': 'anharmonicity',
#                           'unit': 'GHz',
#                           'value': -0.34034053541629083},
#                       {   'date': datetime.datetime(2021, 1, 28, 4, 28, 18, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_error',
#                           'unit': '',
#                           'value': 0.19269999999999998},
#                       {   'date': datetime.datetime(2021, 1, 28, 4, 28, 18, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas0_prep1',
#                           'unit': '',
#                           'value': 0.03759999999999997},
#                       {   'date': datetime.datetime(2021, 1, 28, 4, 28, 18, tzinfo=tzoffset(None, -18000)),
#                           'name': 'prob_meas1_prep0',
#                           'unit': '',
#                           'value': 0.3478},
#                       {   'date': datetime.datetime(2021, 1, 28, 4, 28, 18, tzinfo=tzoffset(None, -18000)),
#                           'name': 'readout_length',
#                           'unit': 'ns',
#                           'value': 5813.333333333333}]]}

# %% [markdown]
# The properties of fake_boeblingen printed above is too much to read, therefore, we will look more closely at a piece of that information here. Specifically, information about the **Identity gate applied to qubit 0** of the backend we chose earlier.
#
#
# 1) `id` represents the identity gate.
#
# 2) `gate_error` represents the probability of the identity gate producing an error when applied to **qubit 0** of the backend. More information **[HERE](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendProperties.gate_error.html#qiskit.providers.models.BackendProperties.gate_error).**
#
# 3) `gate_length` represents the amount of time it takes for the identity gate to be applied to **qubit 0** of the backend. More informaiton **[HERE](https://qiskit.org/documentation/stubs/qiskit.providers.models.BackendProperties.gate_length.html#qiskit.providers.models.BackendProperties.gate_length)**.
#
#
#     `gates': [   {   'gate': 'id',
#                     'name': 'id0',
#                     'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 5, 14, 11, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_error',
#                                            'unit': '',
#                                            'value': 0.00023855765187208629},
#                                        {   'date': datetime.datetime(2021, 2, 3, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                            'name': 'gate_length',
#                                            'unit': 'ns',
#                                            'value': 35.55555555555556}],
#                     'qubits': [0]},
#                      . . .,
#
#      `
#
#
# Here is information about a **CNOT gate** applied to qubit 11 **(control)**, and qubit 10 **(target)** of the backend we chose earlier.
#
# 1) `cx` represents the CNOT gate.
#
# 2) `gate_error` represents the probability of the CNOT gate producing an error when applied to **qubit 11** and **qubit 10** of the backend.
#
# 3) `gate_length` represents the amount of time it takes for the CNOT gate to be applied to **qubit 11** and **qubit 10** of the backend.
#
#              {   'gate': 'cx',
#                  'name': 'cx11_10',
#                  'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 18, 32, 27, tzinfo=tzoffset(None, -18000)),
#                                        'name': 'gate_error',
#                                        'unit': '',
#                                        'value': 0.02155454811899593},
#                                    {   'date': datetime.datetime(2021, 1, 31, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                        'name': 'gate_length',
#                                        'unit': 'ns',
#                                        'value': 632.8888888888888}],
#                  'qubits': [11, 10]},
#                  . . .,
#
# There is similar information for a **CNOT gate** applied to qubit 10 **(this time as control)**, and qubit 11 **(this time as target)**. As you may notice the `gate_length` is different this time, but the `gate_error` has remained the same.
#
#              {   'gate': 'cx',
#                  'name': 'cx10_11',
#                  'parameters': [   {   'date': datetime.datetime(2021, 2, 3, 18, 32, 27, tzinfo=tzoffset(None, -18000)),
#                                        'name': 'gate_error',
#                                        'unit': '',
#                                        'value': 0.02155454811899593},
#                                    {   'date': datetime.datetime(2021, 1, 31, 21, 40, 50, tzinfo=tzoffset(None, -18000)),
#                                        'name': 'gate_length',
#                                        'unit': 'ns',
#                                        'value': 668.4444444444445}],
#                  'qubits': [10, 11]},
#                  . . .,
#
# Now lets print the qubit connectivity(i.e. **coupling_map**) drawing of the backend we chose earlier.

# %%
cm.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=469x674 at 0x27788479EE0>

# %% [markdown]
# ### Step 1:  We begin with a small circuit that implements the BV algorithm for a 3 bit hidden string s.
#
# The source code is found on the Qiskit website, [HERE](https://qiskit.org/textbook/ch-algorithms/bernstein-vazirani.html#3.-Qiskit-Implementation--).

# %%
### Lets defined a new circuit of your choice with no measurements

s = '011'   # the hidden binary string
n = 3 # number of bits used to represent s


# We need a circuit with n qubits, plus one auxiliary qubit
# We also need n classical bits to write the output to
untranspiled_qc = QuantumCircuit(n+1, n)

# Put auxiliary in the minus state |->
# We leave the other n qubits in just |0>
untranspiled_qc.h(n)
untranspiled_qc.z(n)

# Apply Hadamard gates to each of the n "main" qubits (excluding the auxiliary)
# before querying the oracle
for i in range(n):
    untranspiled_qc.h(i)
    
# Apply barrier
untranspiled_qc.barrier()

# Apply the inner-product oracle
s = s[::-1] # reverse s to fit qiskit's qubit ordering
for q in range(n):
    if s[q] == '0':
        untranspiled_qc.i(q)
    else:
        untranspiled_qc.cx(q, n)
        
# Apply barrier
untranspiled_qc.barrier()

# Apply Hadamard gates after querying the oracle
for i in range(n):
    untranspiled_qc.h(i)


# Measurement
for i in range(n):
    untranspiled_qc.measure(i, i)


untranspiled_qc = transpile(untranspiled_qc, backend=None)  # No Optimization and no mapping because we have not specified a backend.
print('No Optimization')
print('Depth:', untranspiled_qc.depth())
print('Gate counts:', untranspiled_qc.count_ops())
untranspiled_qc.draw()
# Out:
# No Optimization
# Depth: 6
# Gate counts: OrderedDict([('h', 7), ('measure', 3), ('barrier', 2), ('cx', 2), ('z', 1), ('id', 1)])
#      ┌───┐      ░                 ░ ┌───┐┌─┐
# q_0: ┤ H ├──────░───■─────────────░─┤ H ├┤M├──────
#      ├───┤      ░   │             ░ ├───┤└╥┘┌─┐
# q_1: ┤ H ├──────░───┼─────────■───░─┤ H ├─╫─┤M├───
#      ├───┤      ░   │  ┌───┐  │   ░ ├───┤ ║ └╥┘┌─┐
# q_2: ┤ H ├──────░───┼──┤ I ├──┼───░─┤ H ├─╫──╫─┤M├
#      ├───┤┌───┐ ░ ┌─┴─┐└───┘┌─┴─┐ ░ └───┘ ║  ║ └╥┘
# q_3: ┤ H ├┤ Z ├─░─┤ X ├─────┤ X ├─░───────╫──╫──╫─
#      └───┘└───┘ ░ └───┘     └───┘ ░       ║  ║  ║
# c: 3/═════════════════════════════════════╩══╩══╩═
#                                           0  1  2

# %% [markdown]
# Print DAG of **untranspiled** circuit.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import circuit_to_dag
from qiskit.tools.visualization import dag_drawer

# Required software to visually see DAG
# !pip install pydot

# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(untranspiled_qc)
dag_drawer(dag)
# Out:
# Requirement already satisfied: pydot in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (from pydot) (2.4.7)
# <PIL.Image.Image image mode=RGBA size=485x824 at 0x277885A8F10>

# %% [markdown]
# Print Measurement Results

# %%
from qiskit.tools.visualization import plot_histogram
#from qiskit import Aer
#results_BV = Aer.get_backend('aer_simulator').run(untranspiled_qc, shots=5000).result()


results_BV = simulated_backend.run(untranspiled_qc, shots=1024).result()
counts = results_BV.get_counts()
plot_histogram(counts)

# %% [markdown]
# ### Step 2: Set up a Logger
#
# Here, we will **save the passes used in the predefined transpilation pipeline of optimization_level=0**. Do not worry about this for now, we will use this later.
#
# For more information about logging the list of transpilation passes for a predefined transpilation process, click **[HERE](https://qiskit.org/documentation/tutorials/circuits_advanced/04_transpiler_passes_and_passmanager.html#Transpiler-Logging)**.
#
# For information about Logging, click **[HERE](https://docs.python.org/3/library/logging.html#levels)**.

# %%
import logging 

# Create and configure logger 
logging.basicConfig(filename="B-V_opt_lv3_passes.txt", filemode='w', format='%(asctime)s %(message)s') 

# Create an object 
logger=logging.getLogger('qiskit.transpiler') 

logger.setLevel('INFO')

formatter = logging.Formatter('%(asctime)s --- %(name)s --- %(processName)-10s --- %(levelname)s: %(message)s')
handler = logging.getLogger().handlers[0]
handler.setFormatter(formatter)

# %% [markdown]
# ### Step 3: Transpile using `optimization_level=0`
#
# This option does no optimization, so you end up using your input circuit on your hardware exactly as its been defined. This will give bad results, because your circuit does not even consider the device connectivity, there is no reduction of swap gates, etc.

# %%
transpiled_qc0 = transpile(untranspiled_qc, simulated_backend, optimization_level=3)  # No Optimization
print('Optimization Level 0')
print('Depth:', transpiled_qc0.depth())
print('Gate counts:', transpiled_qc0.count_ops())

# Print transpiled circuit
transpiled_qc0.draw()

# %% [markdown]
# Print DAG of **transpiled** circuit that used **optimization_level=0**.

# %%
# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(transpiled_qc0)
dag_drawer(dag)

# %% [markdown]
# Print Measurement Results

# %%
results_BV_Lev0 = simulated_backend.run(transpiled_qc0, shots=1024).result()
counts = results_BV_Lev0.get_counts()
plot_histogram(counts)

# %% [markdown]
# ### Step: 4: Print passes used in `optimization_level=0`

# %%
path = "C:/Users/Danie/Documents/New/PIRQ_Draft/"+"Module 2"+"/Gate_Optimization/B-V_opt_lv0_passes.txt"

f = open(path, 'r')
content = f.read()
print(content)
f.close()

# %% [markdown]
# As you can see above, there are multiple passes used when `optimization_level=0`. Our goalnow is to:
#
# 1. Pass this exact sequence of passes to a new PassManager object
# 2. Use the PassManager Object on our untranspiled B-V circuit
# 3. Obtain the same circuit as the transpiled B-V circuit using optimization_level=0

# %% [markdown]
# ### Step 5: Read text file containing all transpiler passes, store transpiler passes into a Pass Manager object.

# %%
# Read in file and store passes into PassManager object
# TODO



# Create a customized transpilation pipeline.
pm = PassManager()
# Pass 1: TODO
# pm.append(<pass_here>)



# Print out diagram of PassManager to see the list of passes we are currently using.
pm.draw()

# %% [markdown]
# Use **your transpilation pipeline** on the **untranspiled circuit**, then print you **new transpiled circuit**.
#
# Because we used the same passes as the predefined transpilation process that used `optimization_level=0`, then we expect the same circuit.

# %%
my_transpiled_qc = pm.run(untranspiled_qc)
my_transpiled_qc.draw()

# %% [markdown]
# Print DAG of **transpiled** circuit that used **your transpilation pipeline**.
#
# Similarly, we expect the same DAG.

# %%
# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(my_transpiled_qc)
dag_drawer(dag)

# %% [markdown]
# Print Measurement Results

# %%
from qiskit.tools.visualization import plot_histogram

results_BV = simulated_backend.run(my_transpiled_qc).result()
counts = results_BV.get_counts()
plot_histogram(counts)

# %% [markdown]
# ### Step 6: Done
