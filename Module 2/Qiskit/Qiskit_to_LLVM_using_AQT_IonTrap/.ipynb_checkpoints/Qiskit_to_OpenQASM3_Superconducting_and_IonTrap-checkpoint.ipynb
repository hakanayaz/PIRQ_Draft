# %% [markdown]
# # Qiskit to OpenQASM3 Superconducting and IonTrap
#
# Three steps:
#
# 0. Choose a Quantum Algorithm. Using Berstein Vazirani for a 3 bit hidden string s.
# 1. Creating transpiled circuit at optimization_level=3 with Superconducting backend to OpenQASM3.
# 2. Creating transpiled circuit at optimization_level=3 with Ion Trap backend to OpenQASM3.

# %% [markdown]
# ## Step 0: Write the Bernstein Vazirani algorithm for a 3 bit hidden string s, in Qiskit.

# %%
# Write simplified Bernstein Vazirani algorithm from scratch using Qiskit
from qiskit import QuantumCircuit
from qiskit.visualization import circuit_drawer
from qiskit.compiler import transpile


s = '011'   # the hidden binary string
n = 3 # number of bits used to represent s


# We need a circuit with n qubits, plus one auxiliary qubit
# We also need n classical bits to write the output to
qiskit_untranspiled_qc = QuantumCircuit(n+1, n)

# Put auxiliary in the minus state |->
# We leave the other n qubits in just |0>
qiskit_untranspiled_qc.h(n)
qiskit_untranspiled_qc.z(n)

# Apply Hadamard gates to each of the n "main" qubits (excluding the auxiliary)
# before querying the oracle
for i in range(n):
    qiskit_untranspiled_qc.h(i)
    
# Apply barrier
qiskit_untranspiled_qc.barrier()

# Apply the inner-product oracle
s = s[::-1] # reverse s to fit qiskit's qubit ordering
for q in range(n):
    if s[q] == '0':
        pass #qiskit_untranspiled_qc.i(q)
    else:
        qiskit_untranspiled_qc.cx(q, n)
        
# Apply barrier
qiskit_untranspiled_qc.barrier()

# Apply Hadamard gates after querying the oracle
for i in range(n):
    qiskit_untranspiled_qc.h(i)


# Measurement
for i in range(n):
    qiskit_untranspiled_qc.measure(i, i)


qiskit_untranspiled_qc = transpile(qiskit_untranspiled_qc, backend=None)  # No Optimization and no mapping because we have not specified a backend.
print('No Optimization')
print('Depth:', qiskit_untranspiled_qc.depth())
print('Gate counts:', qiskit_untranspiled_qc.count_ops())
qiskit_untranspiled_qc.draw("mpl").savefig("Images/B-V_qiskit_untranspiled_qc.jpg")
# Out:
# No Optimization
# Depth: 6
# Gate counts: OrderedDict([('h', 7), ('measure', 3), ('barrier', 2), ('cx', 2), ('z', 1)])

# %% [markdown]
# #### Logger
# In order to track and report information about transpilation, we'll use a Logger object to help us gain insight into the transpiler.

# %%
import logging

logging.basicConfig(level='DEBUG')
logging.getLogger('qiskit.transpiler').setLevel('INFO')
formatter = logging.Formatter('%(asctime)s --- %(name)s --- %(levelname)s: %(message)s\n')
handler = logging.getLogger().handlers[0]
handler.setFormatter(formatter)

# %% [markdown]
# ## Step 1: Qiskit to OpenQASM3 using IBM Superconducting Qubits
# 1. Load IBM Superconducting Backend.
# 2. Transpilation Optimization_Level=3 with Superconducting Backend. Save DAG, and histogram results.
# 3. Convert transpiled (with IBM Superconducting Backend) circuit to OpenQasm code.
#
# #### Substep 1: Load IBM Superconducting Backend.

# %%
# Define a simulated noisy backend
from qiskit.test.mock import FakeBoeblingen
from qiskit.compiler import transpile

IBM_Superconducting_backend = FakeBoeblingen()
# Out:
# <ipython-input-3-fedd5462cbb0>:2: DeprecationWarning: The module 'qiskit.test.mock' is deprecated since Qiskit Terra 0.21.0, and will be removed 3 months or more later. Instead, you should import the desired object directly 'qiskit.providers.fake_provider'.
#   from qiskit.test.mock import FakeBoeblingen
# 2022-07-08 14:12:40,474 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,475 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,475 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,476 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,477 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,478 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 1.07861 (ms)
#
# 2022-07-08 14:12:40,478 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,479 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,479 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,480 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:40,480 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)

# %% [markdown]
# #### Substep 2: Transpilation Optimization_Level=3 with Superconducting Backend. Save DAG, and histogram results.

# %%
transpiled_Superconducting_qc3 = transpile(qiskit_untranspiled_qc, IBM_Superconducting_backend, optimization_level=3)  # MAXIMUM Optimization!!!
print('Optimization Level 3')
print('Depth:', transpiled_Superconducting_qc3.depth())
print('Gate counts:', transpiled_Superconducting_qc3.count_ops())
transpiled_Superconducting_qc3.draw("mpl").savefig("Images/B-V_transpiled_Superconducting_qc3.jpg")
# Out:
# 2022-07-08 14:12:41,445 --- qiskit.quantum_info.synthesis.two_qubit_decompose --- DEBUG: Requested fidelity: None calculated fidelity: 1.0 actual fidelity 1.0000000000000007
#
# 2022-07-08 14:12:41,450 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,450 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.00000 (ms)
#
# 2022-07-08 14:12:41,450 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.00000 (ms)
#
# 2022-07-08 14:12:41,452 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: OptimizeSwapBeforeMeasure - 0.00000 (ms)
#
# 2022-07-08 14:12:41,452 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveDiagonalGatesBeforeMeasure - 0.00000 (ms)
#
# 2022-07-08 14:12:41,453 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: SetLayout - 0.00000 (ms)
#
# 2022-07-08 14:12:41,489 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: VF2Layout - 35.07757 (ms)
#
# 2022-07-08 14:12:41,491 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FullAncillaAllocation - 0.99492 (ms)
#
# 2022-07-08 14:12:41,492 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: EnlargeWithAncilla - 0.00000 (ms)
#
# 2022-07-08 14:12:41,495 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ApplyLayout - 2.05779 (ms)
#
# 2022-07-08 14:12:41,498 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CheckMap - 0.00000 (ms)
#
# 2022-07-08 14:12:41,498 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,499 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:41,499 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('h', 1), ('barrier', 4), ('z', 1), ('measure', 1), ('cx', 2)} to target basis {'id', 'u1', 'u3', 'reset', 'snapshot', 'barrier', 'measure', 'cx', 'u2', 'delay'}.
#
# 2022-07-08 14:12:41,501 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.001s.
#
# 2022-07-08 14:12:41,503 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.001s.
#
# 2022-07-08 14:12:41,504 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.001s.
#
# 2022-07-08 14:12:41,504 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 4.91548 (ms)
#
# 2022-07-08 14:12:41,505 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.00000 (ms)
#
# 2022-07-08 14:12:41,505 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:41,506 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,507 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:41,508 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,508 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:41,514 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 5.00154 (ms)
#
# 2022-07-08 14:12:41,515 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,517 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 2.00820 (ms)
#
# 2022-07-08 14:12:41,518 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 1.00899 (ms)
#
# 2022-07-08 14:12:41,519 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.00000 (ms)
#
# 2022-07-08 14:12:41,520 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,520 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:41,521 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('u2', 1), ('barrier', 4)} to target basis {'id', 'u1', 'u3', 'reset', 'snapshot', 'barrier', 'measure', 'cx', 'u2', 'delay'}.
#
# 2022-07-08 14:12:41,521 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:41,522 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-07-08 14:12:41,523 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-07-08 14:12:41,524 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 2.99907 (ms)
#
# 2022-07-08 14:12:41,524 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:41,525 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,525 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:41,525 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,526 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:41,528 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 1.99986 (ms)
#
# 2022-07-08 14:12:41,529 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,530 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.99444 (ms)
#
# 2022-07-08 14:12:41,531 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,532 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.00000 (ms)
#
# 2022-07-08 14:12:41,532 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,533 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:41,533 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('u2', 1), ('barrier', 4)} to target basis {'id', 'u1', 'u3', 'reset', 'snapshot', 'barrier', 'measure', 'cx', 'u2', 'delay'}.
#
# 2022-07-08 14:12:41,534 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:41,535 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.001s.
#
# 2022-07-08 14:12:41,535 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-07-08 14:12:41,536 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 3.00026 (ms)
#
# 2022-07-08 14:12:41,536 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:41,538 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,538 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:41,539 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:41,539 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:41,541 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 1.01089 (ms)
#
# 2022-07-08 14:12:41,542 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,543 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 0.99087 (ms)
#
# 2022-07-08 14:12:41,543 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,544 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.00000 (ms)
#
# 2022-07-08 14:12:41,544 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:41,545 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
# 2022-07-08 14:12:41,545 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('u2', 1), ('barrier', 4)} to target basis {'id', 'u1', 'u3', 'reset', 'snapshot', 'barrier', 'measure', 'cx', 'u2', 'delay'}.
#
# 2022-07-08 14:12:41,545 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:41,546 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-07-08 14:12:41,546 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-07-08 14:12:41,547 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.99032 (ms)
#
# 2022-07-08 14:12:41,547 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00000 (ms)
#
# 2022-07-08 14:12:41,548 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 1056.20289 (ms)
#
# 2022-07-08 14:12:41,627 --- matplotlib.axes._base --- DEBUG: top of axes not in the figure, so title not moved
# Optimization Level 3
# Depth: 5
# Gate counts: OrderedDict([('u2', 7), ('measure', 3), ('barrier', 2), ('cx', 2)])
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=8.0.
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:41,990 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,995 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:41,995 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,995 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,996 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:41,997 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,998 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:41,998 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:41,999 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,000 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,000 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,000 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,001 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,001 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,002 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,002 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
#
# 2022-07-08 14:12:42,003 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
#
# 2022-07-08 14:12:42,003 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,004 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,004 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,005 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,005 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,005 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,006 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,006 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
#
# 2022-07-08 14:12:42,006 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,007 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,007 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,007 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,008 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,008 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
#
# 2022-07-08 14:12:42,008 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,010 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,011 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,011 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,012 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,012 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,013 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,013 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,014 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framdit.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,014 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,015 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,015 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,016 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
#
# 2022-07-08 14:12:42,016 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,016 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,017 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
# 2022-07-08 14:12:42,017 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,018 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,018 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,018 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,020 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,020 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Kristen ITC' (ITCKRIST.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,021 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,021 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,021 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,022 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,022 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,022 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,023 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Algerian' (ALGER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,023 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,024 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,024 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Forte' (FORTE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,024 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,025 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,025 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,025 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,026 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,028 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,028 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:42,028 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,029 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,030 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,030 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,031 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,031 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,032 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,032 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,032 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,033 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,033 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,034 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,034 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,035 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal 290 normal>) = 10.1545
#
# 2022-07-08 14:12:42,035 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,036 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
#
# 2022-07-08 14:12:42,037 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,037 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,038 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,038 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
#
# 2022-07-08 14:12:42,038 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,039 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,039 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,039 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,040 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constanb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,040 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,041 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,041 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,042 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,042 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,042 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWAD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,043 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERB____.TTF) normal normal 700 normal>) = 10.335
# 2022-07-08 14:12:42,043 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,044 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,044 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,045 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_B.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,045 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,046 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,046 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,047 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,048 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,048 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:42,049 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,049 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,049 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,050 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,050 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,050 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,051 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,051 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
#
# 2022-07-08 14:12:42,052 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
#
# 2022-07-08 14:12:42,052 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,052 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,053 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCBI____.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,053 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,055 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,055 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADM.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,055 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,056 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,056 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Colonna MT' (COLONNA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,056 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,057 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,057 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,057 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,058 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,059 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,059 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,060 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:42,060 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,061 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,061 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,062 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,062 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,062 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (CENSCBK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,063 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,063 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,064 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,065 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (BKANT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,065 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,066 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,067 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSD.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,067 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,067 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,068 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,068 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,069 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-07-08 14:12:42,070 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,070 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,071 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,071 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,071 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWDB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,072 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,072 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,072 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:42,073 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,073 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,073 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,074 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:42,074 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,074 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,074 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXD.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,074 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,075 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,075 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAI.TTF) italic normal 900 normal>) = 11.525
#
# 2022-07-08 14:12:42,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Berlin Sans FB Demi' (BRLNSDB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,077 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,078 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,080 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palace Script MT' (PALSCRI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,080 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,081 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,081 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,082 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,082 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
#
# 2022-07-08 14:12:42,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ravie' (RAVIE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GILB____.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,085 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,085 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Agency FB' (AGENCYB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,085 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:42,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,088 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Informal Roman' (INFROMAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,088 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERTI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABKIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PER_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,091 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,091 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 300 normal>) = 10.145
# 2022-07-08 14:12:42,092 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rage Italic' (RAGE.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,092 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAX.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,092 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,093 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Centaur' (CENTAUR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,093 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,094 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:42,094 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,094 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,095 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,095 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal 900 normal>) = 10.525
#
# 2022-07-08 14:12:42,096 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,096 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,098 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,098 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,099 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,099 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,100 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,100 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,100 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
#
# 2022-07-08 14:12:42,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,102 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,102 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,102 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,102 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:42,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
#
# 2022-07-08 14:12:42,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,104 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,104 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,104 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>) = 10.05
#
# ...
#
# 2022-07-08 14:12:42,120 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,121 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,121 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,121 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,122 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
#
# 2022-07-08 14:12:42,122 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal 800 normal>) = 10.43
#
# 2022-07-08 14:12:42,123 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,123 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,123 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,124 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,124 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,124 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,125 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,125 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,125 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
#
# 2022-07-08 14:12:42,126 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,126 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
#
# 2022-07-08 14:12:42,127 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,128 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,128 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,129 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,129 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
#
# 2022-07-08 14:12:42,130 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,131 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal 900 normal>) = 10.525
#
# 2022-07-08 14:12:42,131 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
#
# 2022-07-08 14:12:42,132 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,133 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,133 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,133 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,134 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,135 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,135 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,135 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:42,136 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,136 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,136 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,137 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
#
# 2022-07-08 14:12:42,137 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,138 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,138 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,138 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,139 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:42,139 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,139 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,140 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
#
# 2022-07-08 14:12:42,140 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:42,141 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,141 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,141 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,142 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,142 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,142 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2022-07-08 14:12:42,143 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,143 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:42,143 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comicz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,144 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
#
# 2022-07-08 14:12:42,145 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CB.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:42,145 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,146 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,146 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Medium Cond' (FRAMDCN.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,147 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,147 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,147 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,148 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:42,148 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,148 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,149 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,149 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,149 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,150 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,150 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
#
# 2022-07-08 14:12:42,150 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,151 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Jokerman' (JOKERMAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,151 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,151 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Outlook' (OUTLOOK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,152 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,152 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,153 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,153 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,153 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:42,154 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,154 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,154 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,155 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,155 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 expanded>) = 10.25
#
# 2022-07-08 14:12:42,155 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,156 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,156 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:42,156 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,157 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bradley Hand ITC' (BRADHITC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,157 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,157 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,158 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,158 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,158 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:42,159 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,159 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,163 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,164 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Print' (segoeprb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,164 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:42,165 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,165 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:42,165 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:42,166 --- matplotlib.font_manager --- DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=8.0 to DejaVu Sans ('C:\\Users\\Danie\\anaconda3\\envs\\PIRQ_Project\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import circuit_to_dag
from qiskit.tools.visualization import dag_drawer

# Required software to visually see DAG
# !pip install pydot

# Draw DAG of the transpiled circuit that used optimization_level=3
dag = circuit_to_dag(transpiled_Superconducting_qc3)
dag_drawer(dag, filename="Images/B-V_transpiled_Superconducting_qc3_dag.jpg")
# Out:
# Requirement already satisfied: pydot in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\danie\anaconda3\envs\pirq_project\lib\site-packages (from pydot) (2.4.7)

# %%
from qiskit.tools.visualization import plot_histogram

results_BV_Lev3 = IBM_Superconducting_backend.run(transpiled_Superconducting_qc3).result()
counts = results_BV_Lev3.get_counts()
plot_histogram(counts, filename="Images/B-V_transpiled_Superconducting_qc3_histogram.jpg")
# Out:
# 2022-07-08 14:12:46,399 --- qiskit.compiler.assembler --- INFO: Total Assembly Time - 0.00000 (ms)
#
# 2022-07-08 14:12:46,695 --- matplotlib.font_manager --- DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=14.0.
#
# 2022-07-08 14:12:46,700 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,700 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,700 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,700 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,702 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,702 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,703 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,703 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,704 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,705 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,705 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,706 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,706 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,707 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,707 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,708 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,709 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,709 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,710 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,711 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,711 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
#
# 2022-07-08 14:12:46,712 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
#
# 2022-07-08 14:12:46,712 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,713 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,713 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,714 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,715 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,715 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,716 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,716 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
#
# 2022-07-08 14:12:46,716 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,717 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,717 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,719 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,719 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,721 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
#
# 2022-07-08 14:12:46,721 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,721 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,722 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,722 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,723 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,723 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,723 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,724 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,724 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framdit.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,724 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,725 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:46,726 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,727 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
#
# 2022-07-08 14:12:46,727 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,728 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>) = 10.05
# 2022-07-08 14:12:46,728 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,728 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,729 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,729 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,730 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,731 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,731 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Kristen ITC' (ITCKRIST.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,731 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,732 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,733 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,733 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,734 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,734 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,734 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Algerian' (ALGER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,735 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,735 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,735 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Forte' (FORTE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,736 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:46,736 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,736 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,737 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,737 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,737 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,738 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:46,738 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,739 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,739 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,739 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,740 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,740 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,741 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,741 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,742 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,742 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,742 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,743 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,743 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,744 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal 290 normal>) = 10.1545
#
# 2022-07-08 14:12:46,744 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,744 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
#
# 2022-07-08 14:12:46,745 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,745 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,746 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,748 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
#
# 2022-07-08 14:12:46,749 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,749 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,750 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,750 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,751 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constanb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,753 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,753 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,753 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,754 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:46,754 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,754 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWAD.TTF) normal normal 400 normal>) = 10.05
# 2022-07-08 14:12:46,755 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERB____.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,756 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,757 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,757 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,758 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_B.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,758 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,759 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,762 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,762 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,762 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,763 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:46,764 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,764 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,766 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,767 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,767 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,768 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,769 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,769 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
#
# 2022-07-08 14:12:46,770 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
#
# 2022-07-08 14:12:46,771 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,771 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,771 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCBI____.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,772 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,772 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,773 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADM.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,773 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,774 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,774 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Colonna MT' (COLONNA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,775 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,775 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,776 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,776 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,777 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:46,777 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,778 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,778 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:46,779 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,779 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,780 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,780 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,781 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,781 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (CENSCBK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,781 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,782 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,785 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,785 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (BKANT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,786 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,786 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,787 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSD.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:46,787 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,789 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,790 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,790 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,790 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-07-08 14:12:46,791 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,791 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,792 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,792 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,792 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWDB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,793 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,793 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,794 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:46,794 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,794 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,795 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,795 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:46,797 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,797 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,798 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXD.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:46,799 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,799 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,799 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAI.TTF) italic normal 900 normal>) = 11.525
#
# 2022-07-08 14:12:46,800 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,800 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,800 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Berlin Sans FB Demi' (BRLNSDB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,801 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,801 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,802 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Palace Script MT' (PALSCRI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,802 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,802 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,803 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,803 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,804 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
#
# 2022-07-08 14:12:46,804 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,804 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,805 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ravie' (RAVIE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,806 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,806 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,807 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GILB____.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,807 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,808 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Agency FB' (AGENCYB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,808 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:46,808 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,809 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,809 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,809 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:46,810 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,810 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,810 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Informal Roman' (INFROMAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,811 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,811 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,812 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERTI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,812 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,812 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,813 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABKIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,813 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,814 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PER_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,814 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,816 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 300 normal>) = 10.145
# 2022-07-08 14:12:46,816 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rage Italic' (RAGE.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,816 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAX.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,818 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,819 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Centaur' (CENTAUR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,819 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,820 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:46,820 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,821 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,821 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,821 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal 900 normal>) = 10.525
#
# 2022-07-08 14:12:46,822 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,822 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,822 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,823 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,824 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,824 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,825 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,825 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,825 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,826 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,827 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,827 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:46,828 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,828 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
#
# 2022-07-08 14:12:46,828 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,829 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,829 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,830 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,830 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,830 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:46,831 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
#
# 2022-07-08 14:12:46,831 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,831 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,833 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,833 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,834 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,834 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,835 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,835 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,835 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ariblk.ttf) normal normal 900 normal>) = 6.888636363636364
#
# 2022-07-08 14:12:46,836 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GILBI___.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,836 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consola.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,837 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Constantia' (constanz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,837 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,838 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,838 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Elephant' (ELEPHNTI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,839 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Felix Titling' (FELIXTI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,839 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,840 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Bold ITC' (ERASBD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,840 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPE.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,841 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,841 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Symbol' (symbol.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,842 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,842 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:46,842 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal 290 normal>) = 10.1545
# 2022-07-08 14:12:46,843 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Onyx' (ONYX.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,844 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal 300 normal>) = 11.145
#
# 2022-07-08 14:12:46,845 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbell.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,845 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,846 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,847 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,847 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,848 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
#
# 2022-07-08 14:12:46,848 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal 800 normal>) = 10.43
#
# 2022-07-08 14:12:46,849 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,849 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,850 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,850 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,851 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,851 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,852 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,853 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,854 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
#
# 2022-07-08 14:12:46,855 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,855 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
#
# 2022-07-08 14:12:46,856 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,856 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,857 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:46,859 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,859 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
#
# 2022-07-08 14:12:46,860 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,860 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal 900 normal>) = 10.525
#
# 2022-07-08 14:12:46,861 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
#
# 2022-07-08 14:12:46,862 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:46,862 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,863 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,863 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,864 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:46,864 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,865 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:46,866 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:46,866 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,867 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,867 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:46,868 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
#
# 2022-07-08 14:12:46,868 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:46,869 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:46,869 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
#
# ...
#
# 2022-07-08 14:12:47,075 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,075 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,075 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:47,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
#
# 2022-07-08 14:12:47,076 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal 800 normal>) = 10.43
#
# 2022-07-08 14:12:47,078 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,078 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,079 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,079 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,080 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,080 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,080 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,081 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,081 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
#
# 2022-07-08 14:12:47,081 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,082 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
#
# 2022-07-08 14:12:47,082 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,082 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,083 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
#
# 2022-07-08 14:12:47,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal 900 normal>) = 10.525
#
# 2022-07-08 14:12:47,084 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
#
# 2022-07-08 14:12:47,085 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:47,085 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,086 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:47,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:47,087 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal 350 normal>) = 10.0975
#
# 2022-07-08 14:12:47,088 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,088 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,088 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
#
# 2022-07-08 14:12:47,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,089 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,090 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal 300 normal>) = 10.145
#
# 2022-07-08 14:12:47,091 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,091 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,091 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
#
# 2022-07-08 14:12:47,096 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:47,096 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,096 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,097 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:47,098 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,098 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 2022-07-08 14:12:47,098 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
#
# 2022-07-08 14:12:47,099 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comicz.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,099 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
#
# 2022-07-08 14:12:47,099 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CB.TTF) normal normal 700 condensed>) = 10.535
#
# 2022-07-08 14:12:47,100 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:47,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Medium Cond' (FRAMDCN.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:47,101 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,102 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal 400 condensed>) = 10.25
#
# 2022-07-08 14:12:47,103 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,104 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,104 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,105 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,105 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,106 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,106 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
#
# 2022-07-08 14:12:47,107 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,107 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Jokerman' (JOKERMAN.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,107 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:47,108 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'MS Outlook' (OUTLOOK.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,108 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,108 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,109 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,109 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,110 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
#
# 2022-07-08 14:12:47,110 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,111 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,111 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,111 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Perpetua' (PERI____.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,111 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 expanded>) = 10.25
#
# 2022-07-08 14:12:47,112 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,112 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKBI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,113 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
#
# 2022-07-08 14:12:47,113 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,113 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bradley Hand ITC' (BRADHITC.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,116 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,117 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,117 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,118 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,118 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 500 normal>) = 10.145
#
# 2022-07-08 14:12:47,119 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,119 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,119 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,120 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Print' (segoeprb.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,120 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
#
# 2022-07-08 14:12:47,120 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,121 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
#
# 2022-07-08 14:12:47,121 --- matplotlib.font_manager --- DEBUG: findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
#
# 2022-07-08 14:12:47,121 --- matplotlib.font_manager --- DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\Danie\\anaconda3\\envs\\PIRQ_Project\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# #### Substep3: Convert transpiled (with IBM Superconducting Backend) circuit to OpenQasm code.

# %%
# Qiskit Circuit  <-->  .qasm file
from qiskit import qasm3

# Qiskit -> OpenQASM3
# Print
print(qasm3.dumps(transpiled_Superconducting_qc3))
# Dump to file
with open("B-V_transpiled_Superconducting_qc3.qasm", 'w+') as fp:
    qasm3.dump(transpiled_Superconducting_qc3, fp)
# Out:
# OPENQASM 3;
# include "stdgates.inc";
# bit[3] c;
# u2(0, pi) $0;
# u2(0, pi) $11;
# u2(0, pi) $15;
# u2(-pi, -pi) $16;
# barrier $11, $15, $0, $16;
# cx $11, $16;
# cx $15, $16;
# barrier $11, $15, $0, $16;
# u2(0, pi) $0;
# u2(0, pi) $11;
# u2(0, pi) $15;
# c[0] = measure $11;
# c[1] = measure $15;
# c[2] = measure $0;

# %% [markdown]
# ## Step 2: Qiskit to OpenQASM3 using AQT IonTrap Qubits
# 1. Load the AQT Ion Trap Backend
# 2. Transpilation Optimization_Level=3 with IonTrap Backend. Save DAG, and histogram results.
# 3. Convert transpiled (with AQT IonTrap Backend) circuit to OpenQasm code.

# %% [markdown]
# #### Substep 1: Load the AQT Ion Trap Backend
# 1. To use the AQT Ion Trap backend in Qiskit you must first install the following in your terminal: `pip install qiskit-aqt-provider`
#
# 2. To gain access to the AQT Ion Trap backend you must make an AQT cloud access account **[HERE](https://www.aqt.eu/qc-systems/)**, and use the API key provided by AQT.
#
# For more information about using the AQT Ion Trap backend in Qiskit, please click **[HERE](https://qiskit.org/documentation/partners/aqt/install.html).**

# %%
from qiskit_aqt_provider import AQTProvider

# Input AQT Cloud access API key.
aqt = AQTProvider('151d4eeaea5e4e438dca82276ecf524e')
print("List of AQT Ion Trap Backends: ", aqt.backends(), "\n")

# Choose an AQT Backend. 
AQT_IonTrap_backend = aqt.get_backend('aqt_qasm_simulator_noise_1')
# Out:
# List of AQT Ion Trap Backends:  [<AQTSimulator('aqt_qasm_simulator')>, <AQTSimulatorNoise1('aqt_qasm_simulator_noise_1')>, <AQTDevice('aqt_innsbruck')>]

# %%
from qiskit.tools.jupyter import *
from qiskit.transpiler import CouplingMap
import pprint
pp = pprint.PrettyPrinter(indent=4)


# Print out basic features of this backend. Note, I am using a function found in Backend_General_Information
print("---------------------------------Backend Configuration---------------------------------")

config = AQT_IonTrap_backend.configuration()
pp.pprint(config.to_dict())
#cm = CouplingMap(config.coupling_map)

print("---------------------------------Backend Properties---------------------------------")
# Print out information about the Properties of the backend.
#properties = AQT_IonTrap_backend.properties()
#pp.pprint(properties.to_dict())

#cm.draw()
# Out:
# ---------------------------------Backend Configuration---------------------------------
# {   'backend_name': 'aqt_qasm_simulator_noise_1',
#     'backend_version': '0.0.1',
#     'basis_gates': ['rx', 'ry', 'rxx'],
#     'conditional': False,
#     'coupling_map': None,
#     'description': 'AQT trapped-ion device simulator with noise model 1',
#     'dynamic_reprate_enabled': False,
#     'gates': [{'name': 'TODO', 'parameters': [], 'qasm_def': 'TODO'}],
#     'local': False,
#     'max_experiments': 1,
#     'max_shots': 200,
#     'memory': False,
#     'n_qubits': 11,
#     'open_pulse': False,
#     'simulator': True,
#     'url': 'https://gateway.aqt.eu/marmot/sim/noise-model-1'}
# ---------------------------------Backend Properties---------------------------------

# %% [markdown]
# #### (Optional Substep): Optimization_Level=0

# %%
transpiled_IonTrap_qc0 = transpile(qiskit_untranspiled_qc, AQT_IonTrap_backend, optimization_level=0)
transpiled_IonTrap_qc0.draw("mpl").savefig("Images/B-V_transpiled_IonTrap_qc0.jpg")
# Out:
# 2022-07-08 14:12:47,901 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.99969 (ms)
#
# 2022-07-08 14:12:47,901 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:47,902 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('h', 1), ('barrier', 4), ('z', 1), ('measure', 1), ('cx', 2)} to target basis {'snapshot', 'barrier', 'rxx', 'measure', 'rx', 'ry', 'delay', 'reset'}.
#
# 2022-07-08 14:12:47,904 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.001s.
#
# 2022-07-08 14:12:47,907 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.002s.
#
# 2022-07-08 14:12:47,909 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.001s.
#
# 2022-07-08 14:12:47,909 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 7.00092 (ms)
#
# 2022-07-08 14:12:47,910 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00000 (ms)
#
# 2022-07-08 14:12:47,910 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 10.98824 (ms)
#
# 2022-07-08 14:12:47,985 --- matplotlib.axes._base --- DEBUG: top of axes not in the figure, so title not moved

# %%
# Draw DAG of the transpiled circuit that used optimization_level=0
dag = circuit_to_dag(transpiled_IonTrap_qc0)
dag_drawer(dag, filename="Images/B-V_transpiled_IonTrap_qc0_dag.jpg")

# %%
# Lets execute the transpiled circuit on the simulated noisy backend
results = AQT_IonTrap_backend.run(transpiled_IonTrap_qc0).result()

# Lets get the results of the executed circuit
counts = results.get_counts()
plot_histogram(counts, filename="Images/B-V_transpiled_IonTrap_qc0_histogram.jpg")
# Out:
# 2022-07-08 14:12:48,293 --- urllib3.connectionpool --- DEBUG: Starting new HTTPS connection (1): gateway.aqt.eu:443
#
# 2022-07-08 14:12:49,246 --- urllib3.connectionpool --- DEBUG: https://gateway.aqt.eu:443 "PUT /marmot/sim/noise-model-1 HTTP/1.1" 200 64
#
# 2022-07-08 14:12:49,257 --- urllib3.connectionpool --- DEBUG: Starting new HTTPS connection (1): gateway.aqt.eu:443
#
# 2022-07-08 14:12:50,065 --- urllib3.connectionpool --- DEBUG: https://gateway.aqt.eu:443 "PUT /marmot/sim/noise-model-1 HTTP/1.1" 200 None

# %% [markdown]
# #### Substep 2: Transpilation Optimization_Level=3 with IonTrap Backend.

# %%
transpiled_IonTrap_qc3 = transpile(qiskit_untranspiled_qc, AQT_IonTrap_backend, optimization_level=3)
transpiled_IonTrap_qc3.draw('mpl').savefig("Images/B-V_transpiled_IonTrap_qc3.jpg")
# Out:
# 2022-07-08 14:12:50,145 --- qiskit.quantum_info.synthesis.two_qubit_decompose --- DEBUG: Requested fidelity: None calculated fidelity: 1.0 actual fidelity 1.0000000000000004
#
# 2022-07-08 14:12:50,148 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,149 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Unroll3qOrMore - 0.00000 (ms)
#
# 2022-07-08 14:12:50,149 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.00000 (ms)
#
# 2022-07-08 14:12:50,150 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: OptimizeSwapBeforeMeasure - 0.00000 (ms)
#
# 2022-07-08 14:12:50,150 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveDiagonalGatesBeforeMeasure - 0.00000 (ms)
#
# 2022-07-08 14:12:50,151 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,151 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:50,152 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('h', 1), ('barrier', 4), ('z', 1), ('measure', 1), ('cx', 2)} to target basis {'snapshot', 'barrier', 'rxx', 'measure', 'rx', 'ry', 'delay', 'reset'}.
#
# 2022-07-08 14:12:50,154 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.002s.
#
# 2022-07-08 14:12:50,156 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.002s.
#
# 2022-07-08 14:12:50,156 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-07-08 14:12:50,157 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 4.99654 (ms)
#
# 2022-07-08 14:12:50,157 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: RemoveResetInZeroState - 0.00000 (ms)
#
# 2022-07-08 14:12:50,158 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:50,159 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,160 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:50,160 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,161 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:50,163 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 2.00844 (ms)
#
# 2022-07-08 14:12:50,164 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,166 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 1.99294 (ms)
#
# 2022-07-08 14:12:50,168 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 1.00017 (ms)
#
# 2022-07-08 14:12:50,169 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.00000 (ms)
#
# 2022-07-08 14:12:50,171 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,171 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:50,171 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rxx', 2), ('ry', 1), ('barrier', 4), ('rx', 1), ('measure', 1)} to target basis {'snapshot', 'barrier', 'rxx', 'measure', 'rx', 'ry', 'delay', 'reset'}.
#
# 2022-07-08 14:12:50,172 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:50,173 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-07-08 14:12:50,174 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.001s.
#
# 2022-07-08 14:12:50,174 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 3.00002 (ms)
#
# 2022-07-08 14:12:50,174 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:50,175 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,175 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:50,176 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,176 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:50,179 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 1.99819 (ms)
#
# 2022-07-08 14:12:50,180 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.99993 (ms)
#
# 2022-07-08 14:12:50,182 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 1.99986 (ms)
#
# 2022-07-08 14:12:50,183 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 1.58978 (ms)
#
# 2022-07-08 14:12:50,184 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.50473 (ms)
#
# 2022-07-08 14:12:50,184 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,184 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.00000 (ms)
#
# 2022-07-08 14:12:50,185 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rxx', 2), ('ry', 1), ('barrier', 4), ('rx', 1), ('measure', 1)} to target basis {'snapshot', 'barrier', 'rxx', 'measure', 'rx', 'ry', 'delay', 'reset'}.
#
# 2022-07-08 14:12:50,185 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:50,186 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-07-08 14:12:50,187 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.000s.
#
# 2022-07-08 14:12:50,187 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 1.99962 (ms)
#
# 2022-07-08 14:12:50,188 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Depth - 0.00000 (ms)
#
# 2022-07-08 14:12:50,188 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,189 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Size - 0.00000 (ms)
#
# 2022-07-08 14:12:50,189 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: FixedPoint - 0.00000 (ms)
#
# 2022-07-08 14:12:50,189 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Collect2qBlocks - 0.00000 (ms)
#
# 2022-07-08 14:12:50,193 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ConsolidateBlocks - 3.00097 (ms)
#
# 2022-07-08 14:12:50,193 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: Optimize1qGatesDecomposition - 1.99938 (ms)
#
# 2022-07-08 14:12:50,195 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutationAnalysis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,196 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: CommutativeCancellation - 0.00000 (ms)
#
# 2022-07-08 14:12:50,196 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnitarySynthesis - 0.00000 (ms)
#
# 2022-07-08 14:12:50,197 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: UnrollCustomDefinitions - 0.99063 (ms)
#
# 2022-07-08 14:12:50,197 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Begin BasisTranslator from source basis {('rxx', 2), ('ry', 1), ('barrier', 4), ('rx', 1), ('measure', 1)} to target basis {'snapshot', 'barrier', 'rxx', 'measure', 'rx', 'ry', 'delay', 'reset'}.
#
# 2022-07-08 14:12:50,198 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation path search completed in 0.000s.
#
# 2022-07-08 14:12:50,199 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation paths composed in 0.000s.
#
# 2022-07-08 14:12:50,200 --- qiskit.transpiler.passes.basis.basis_translator --- INFO: Basis translation instructions replaced in 0.001s.
# 2022-07-08 14:12:50,200 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: BasisTranslator - 3.00431 (ms)
#
# 2022-07-08 14:12:50,201 --- qiskit.transpiler.runningpassmanager --- INFO: Pass: ContainsInstruction - 0.00000 (ms)
#
# 2022-07-08 14:12:50,202 --- qiskit.compiler.transpiler --- INFO: Total Transpile Time - 66.94674 (ms)
#
# 2022-07-08 14:12:50,267 --- matplotlib.axes._base --- DEBUG: top of axes not in the figure, so title not moved

# %%
# Draw DAG of the transpiled circuit that used optimization_level=3
dag = circuit_to_dag(transpiled_IonTrap_qc3)
dag_drawer(dag, filename="Images/B-V_transpiled_IonTrap_qc3_dag.jpg")

# %%
# Lets execute the transpiled circuit on the simulated noisy backend
results = AQT_IonTrap_backend.run(transpiled_IonTrap_qc3).result()

# Lets get the results of the executed circuit
counts = results.get_counts()
plot_histogram(counts, filename="Images/B-V_transpiled_IonTrap_qc3_histogram.jpg")
# Out:
# 2022-07-08 14:12:50,570 --- urllib3.connectionpool --- DEBUG: Starting new HTTPS connection (1): gateway.aqt.eu:443
#
# 2022-07-08 14:12:51,369 --- urllib3.connectionpool --- DEBUG: https://gateway.aqt.eu:443 "PUT /marmot/sim/noise-model-1 HTTP/1.1" 200 64
#
# 2022-07-08 14:12:51,377 --- urllib3.connectionpool --- DEBUG: Starting new HTTPS connection (1): gateway.aqt.eu:443
#
# 2022-07-08 14:12:52,164 --- urllib3.connectionpool --- DEBUG: https://gateway.aqt.eu:443 "PUT /marmot/sim/noise-model-1 HTTP/1.1" 200 None

# %% [markdown]
# #### Substep 3: Convert transpiled (with AQT IonTrap Backend) circuit to OpenQasm code.

# %%
# Qiskit Circuit  <-->  .qasm file
from qiskit import qasm3

# Qiskit -> OpenQASM3
# Print
print(qasm3.dumps(transpiled_IonTrap_qc3))
# Dump to file
with open("B-V_transpiled_IonTrap_qc3.qasm", 'w+') as fp:
    qasm3.dump(transpiled_IonTrap_qc3, fp)
# Out:
# OPENQASM 3;
# include "stdgates.inc";
# gate rxx_1693535957680(_gate_p_0) _gate_q_0, _gate_q_1 {
#   h _gate_q_0;
#   h _gate_q_1;
#   cx _gate_q_0, _gate_q_1;
#   rz(pi/2) _gate_q_1;
#   cx _gate_q_0, _gate_q_1;
#   h _gate_q_1;
#   h _gate_q_0;
# }
# gate rxx_1693535959120(_gate_p_0) _gate_q_0, _gate_q_1 {
#   h _gate_q_0;
#   h _gate_q_1;
#   cx _gate_q_0, _gate_q_1;
#   rz(pi/2) _gate_q_1;
#   cx _gate_q_0, _gate_q_1;
#   h _gate_q_1;
#   h _gate_q_0;
# }
# bit[3] c;
# qubit[4] _all_qubits;
# let q = _all_qubits[0:3];
# ry(pi/2) q[0];
# rx(pi) q[0];
# ry(pi/2) q[1];
# rx(pi) q[1];
# ry(pi/2) q[2];
# rx(pi) q[2];
# ry(-pi/2) q[3];
# barrier q[0], q[1], q[2], q[3];
# ry(pi/2) q[0];
# rxx_1693535957680(pi/2) q[0], q[3];
# rx(-pi/2) q[0];
# ry(-pi/2) q[0];
# ry(pi/2) q[1];
# rx(-pi) q[3];
# rxx_1693535959120(pi/2) q[1], q[3];
# rx(-pi/2) q[1];
# ry(-pi/2) q[1];
# barrier q[0], q[1], q[2], q[3];
# ry(pi/2) q[0];
# rx(pi) q[0];
# ry(pi/2) q[1];
# rx(pi) q[1];
# ry(pi/2) q[2];
# rx(pi) q[2];
# c[0] = measure q[0];
# c[1] = measure q[1];
# c[2] = measure q[2];
