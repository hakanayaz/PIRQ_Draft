# %% [markdown]
# # Max Cut QAOA - Pennylane
#
# In this notebook, we present an implementation of the Hybrid Max-Cut QAOA using Xanadu's Pennylane Python framework. [Here](https://pennylane.ai/qml/demos/tutorial_qaoa_maxcut.html) is the source for much of this code.
#
# For general information about the maxcut problem, see [here](https://en.wikipedia.org/wiki/Maximum_cut), and for an explanation of QAOA, [here](https://www.youtube.com/watch?v=YpLzSQPrgSc&list=PLOFEBzvs-VvqJwybFxkTiDzhf5E11p8BI&index=13).
#
# While true hybrid classical-quantum compilation should generate a unified IR, we use this as an intermediate step in order to gain a clearer understanding of which aspects of the transpiled quantum circuit change iteration-by-iteration. This will enable us to decide whether a single transpilation might suffice, or whether each iteration requires its own transpilation.
#
# The first step is to import the Pennylane package and set up the graph on which we will search for the maxcut. Make sure you have Pennylane installed:
# ```terminal
# pip install pennylane
# ```

# %%
pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.24.0-py3-none-any.whl (957 kB)
#      |████████████████████████████████| 957 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (1.21.4)
# Collecting autoray>=0.3.1
#   Downloading autoray-0.3.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: scipy in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (1.7.3)
# Collecting autograd
#   Downloading autograd-1.4-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: appdirs in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (1.4.4)
# Collecting pennylane-lightning>=0.24
#   Downloading PennyLane_Lightning-0.24.0-cp39-cp39-macosx_10_15_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: cachetools in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (4.2.2)
# Requirement already satisfied: retworkx in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (0.11.0)
# Collecting semantic-version==2.6
#   Using cached semantic_version-2.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: toml in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: networkx in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane) (2.7.1)
# Collecting ninja
#   Using cached ninja-1.10.2.3-py2.py3-none-macosx_10_9_universal2.macosx_10_9_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (231 kB)
# Requirement already satisfied: future>=0.15.2 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from autograd->pennylane) (0.18.2)
# Installing collected packages: ninja, semantic-version, pennylane-lightning, autoray, autograd, pennylane
# Successfully installed autograd-1.4 autoray-0.3.2 ninja-1.10.2.3 pennylane-0.24.0 pennylane-lightning-0.24.0 semantic-version-2.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pennylane as qml
from pennylane import numpy as np

n_vertices = 4
graph = [(0, 1), (0, 3), (1, 2), (2, 3)]

# %% [markdown]
# As you can see, we specify the number of vertices and define the edge list of the graph. Visually, our graph looks like this:
#
# ![Graph in question](graph.png)
#
# Next, we define the unitaries which will comprise the mixing and cost layers of our QAOA.

# %%
n_qubits = n_vertices

# Mixing operator, which appplies a single-qubit rotation gate to each qubit
def U_B(beta_i):
    for qubit in range(n_qubits):
        qml.RX(2 * beta_i, wires = qubit)

# The cost operator entangles each pair of qubits which share an edge in the graph
def U_C(gamma_i):
    for edge in graph:
        qubit1 = edge[0]
        qubit2 = edge[1]
        qml.CNOT(wires = [qubit1, qubit2])
        qml.RZ(gamma_i, wires = qubit2)
        qml.CNOT(wires = [qubit1, qubit2])

# %% [markdown]
# With these custom unitarys in hand, we can continue on to build the quantum circuit and specify the quantum backend it will run on. We put all of the qubits in a uniform superposition with Hadamard gates, perform the cost and mixing steps _p_ times, and then measure some subset of qubits (or _wires_, in the Pennylane terminology).

# %%
# Backend
device = qml.device("default.qubit", wires = n_qubits, shots = 1)

# Used to measure in the computational basis
pauli_z = [[1, 0], [0, -1]]
pauli_z_2 = np.kron(pauli_z, pauli_z, requires_grad = False)

# The central circuit of the QAOA
def circ(gammas, betas, edge=None, p=1):
    for qubit in range(n_qubits):
        qml.Hadamard(wires = qubit)
    
    for i in range(p):
        U_C(gammas[i])
        U_B(betas[i])

    if edge is None:
        return qml.sample()

    return qml.expval(qml.Hermitian(pauli_z_2, wires = edge))

# We marks this function as a "QNode", meaning it should be run on quantum hardware, and we specify the device
circuit = qml.QNode(circ, device)

fig, ax = qml.draw_mpl(circuit)([1.0], [1.0])

# %% [markdown]
# Finally, we define a utility function `bitstring_to_int` for converting between bit strings and base 10 integers. Now, we're ready to run our QAOA. This takes place in several steps:
#
# 1. Initialize parameters. we somewhat arbitrarily choose gamma, beta = [1.0, 1.0]. If p were > 1, there would of course be more paramaters to initialize.
# 2. Define the "objective function" we wish the classical optimizer to operate on
# 3. Call the classical optimizer, which kicks off a loop:
#     a) Run the objective with current parameters
#     b) Change paramaters in a direction which will decrease the objective
#     c) Repeat
#
# Here, we only allow the optimizer to perform one iteration. The initial objective value, updated parameters, and updated objective function are all printed, as well as the "solution" to the maxcut instance. Note that because `p = 1` and we are only doing one optimization iteration, this will be a very poor approximation.

# %%
# A utility function, used below to translate encode measurements
def bitstring_to_int(bit_string_sample):
    bit_string = "".join(str(bs) for bs in bit_string_sample)
    return int(bit_string, base=2)

def qaoa_maxcut(p=1):
    print("\np={:d}".format(p))

    # Initialize parameters: Beta = 1, Gamma = 1
    init_params = np.array([[1.0], [1.0]], requires_grad = True)

    # Minimize the negative of the objective function
    def objective(params):
        gammas = params[0]
        betas = params[1]
        neg_obj = 0
        for edge in graph:
            # objective for the MaxCut problem
            neg_obj -= 0.5 * (1 - circuit(gammas, betas, edge=edge, p=p))
        return neg_obj
    
    print("Initial objective: {: .7f}".format(-objective(init_params)))

    # initialize optimizer: Adagrad works well empirically
    opt = qml.AdagradOptimizer(stepsize=0.5)

    # optimize parameters in objective
    params = init_params
    steps = 1
    for i in range(steps):
        params = opt.step(objective, params)
        # if (i + 1) % 5 == 0:
        print("Objective after step {:5d}: {: .7f}".format(i + 1, -objective(params)))

    # Once we've arrived at an optimum, sample bitstrings 100 times
    bit_strings = []
    n_samples = 100
    for i in range(0, n_samples):
        bit_strings.append(bitstring_to_int(circuit(params[0], params[1], edge=None, p=p)))

    # print optimal parameters and most frequently sampled bitstring
    counts = np.bincount(np.array(bit_strings))
    most_freq_bit_string = np.argmax(counts)
    print("Optimized (gamma, beta) vectors:\n{}".format(params[:, :p]))
    print("Most frequently sampled bit string is: {:04b}".format(most_freq_bit_string))

    return -objective(params), bit_strings


# perform qaoa on our graph with p=1,2 and
# keep the bitstring sample lists
bitstrings1 = qaoa_maxcut(p=1)[1]
# Out:
# p=1
# Initial objective:  2.0000000
# Objective after step     1:  1.0000000
# Optimized (gamma, beta) vectors:
# [[0.5]
#  [1.5]]
# Most frequently sampled bit string is: 1010

# %% [markdown]
# Now, the main thing we're interested in is how the quantum circuit changes through an iteration. In order to examine this, we will make use of Pennylane's transpiler, and dump both the "before circuit" and the "after circuit" to OpenQASM (through Qiskit).
#
# ## Transpilation
#
# Pennylane has several built in transpilation passes to optimize a circuit. They are available by specifying a _pipeline_, which is then passed into the `.compile()` transform. By default, it's pipeline is
# ```python
# commute_controlled()
# cancel_inverses()
# merge_rotations()
# ```
# which is sufficient for our purposes.

# %%
compiled_circ = qml.compile()(circ)
compiled_circuit = qml.QNode(compiled_circ, device)
fig, ax = qml.draw_mpl(compiled_circuit)([1.0], [1.0])

# %% [markdown]
# It turns out that this circuit is simple enough that the three transpilation passes don't cause any changes, which is fine for our purposes.
#
# Finally, we want to transform our circuit to Qiskit in order to dump to OpenQASM. For this section, we will need to `pip install pennylane-qiskit`.

# %%
pip install pennylane-qiskit
# Out:
# Collecting pennylane-qiskit
#   Downloading PennyLane_qiskit-0.24.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: qiskit>=0.32 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane-qiskit) (0.36.2)
# Requirement already satisfied: numpy in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane-qiskit) (1.21.4)
# Requirement already satisfied: pennylane>=0.23 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane-qiskit) (0.24.0)
# Requirement already satisfied: networkx>=2.2 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane-qiskit) (2.7.1)
# Collecting mthree>=0.17
#   Downloading mthree-1.0.0-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: cython>=0.29 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from mthree>=0.17->pennylane-qiskit) (0.29.28)
# Collecting qiskit-ibmq-provider>=0.19.2
#   Downloading qiskit_ibmq_provider-0.19.2-py3-none-any.whl (240 kB)
#      |████████████████████████████████| 240 kB 30.2 MB/s eta 0:00:01
# Collecting orjson>=3.0.0
#   Downloading orjson-3.7.8-cp39-cp39-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (469 kB)
#      |████████████████████████████████| 469 kB 35.1 MB/s eta 0:00:01
# Requirement already satisfied: psutil in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from mthree>=0.17->pennylane-qiskit) (5.8.0)
# Collecting qiskit-terra>=0.21
#   Downloading qiskit_terra-0.21.0-cp39-cp39-macosx_10_9_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 59.0 MB/s eta 0:00:01�███████████████████████▌     | 5.3 MB 59.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from mthree>=0.17->pennylane-qiskit) (1.7.3)
# Requirement already satisfied: retworkx in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (0.11.0)
# Requirement already satisfied: appdirs in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (1.4.4)
# Requirement already satisfied: cachetools in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (4.2.2)
# Requirement already satisfied: semantic-version==2.6 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (2.6.0)
# Requirement already satisfied: pennylane-lightning>=0.24 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (0.24.0)
# Requirement already satisfied: toml in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (0.10.2)
# Requirement already satisfied: autograd in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (1.4)
# Requirement already satisfied: autoray>=0.3.1 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane>=0.23->pennylane-qiskit) (0.3.2)
# Requirement already satisfied: ninja in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from pennylane-lightning>=0.24->pennylane>=0.23->pennylane-qiskit) (1.10.2.3)
# Requirement already satisfied: qiskit-ignis==0.7.1 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit>=0.32->pennylane-qiskit) (0.7.1)
# Collecting qiskit>=0.32
#   Downloading qiskit-0.37.0.tar.gz (13 kB)
# Requirement already satisfied: qiskit-aer==0.10.4 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit>=0.32->pennylane-qiskit) (0.10.4)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.26.9)
# Requirement already satisfied: requests>=2.19 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2.27.1)
# Requirement already satisfied: websocket-client>=1.0.1 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2.8.2)
# Requirement already satisfied: websockets>=10.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (10.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.1.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (3.5.0)
# Requirement already satisfied: symengine>=0.9 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (0.9.2)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (1.1.1)
# Requirement already satisfied: ply>=3.10 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (3.11)
# Requirement already satisfied: sympy>=1.3 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (1.9)
# Requirement already satisfied: dill>=0.3 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (0.3.5.1)
# Requirement already satisfied: six>=1.5 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2021.5.30)
# Requirement already satisfied: cryptography>=1.3 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (3.4.8)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (1.15.0)
# Requirement already satisfied: pycparser in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider>=0.19.2->mthree>=0.17->pennylane-qiskit) (2.21)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (5.9.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from sympy>=1.3->qiskit-terra>=0.21->mthree>=0.17->pennylane-qiskit) (1.2.1)
# Requirement already satisfied: future>=0.15.2 in /Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages (from autograd->pennylane>=0.23->pennylane-qiskit) (0.18.2)
# Building wheels for collected packages: qiskit
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.37.0-py3-none-any.whl size=12028 sha256=b14fb09c7536f28f3f2a9e75ee64ab38f588b1e3b32d3a0396bf9d1354889c05
#   Stored in directory: /Users/hakanayaz/Library/Caches/pip/wheels/47/fc/8d/241f135a50c81f032d145992d45613db196ae7d97cbe52111a
# Successfully built qiskit
# Installing collected packages: qiskit-terra, qiskit-ibmq-provider, orjson, qiskit, mthree, pennylane-qiskit
#   Attempting uninstall: qiskit-terra
#     Found existing installation: qiskit-terra 0.20.2
#     Uninstalling qiskit-terra-0.20.2:
#       Successfully uninstalled qiskit-terra-0.20.2
#   Attempting uninstall: qiskit-ibmq-provider
#     Found existing installation: qiskit-ibmq-provider 0.19.1
#     Uninstalling qiskit-ibmq-provider-0.19.1:
#       Successfully uninstalled qiskit-ibmq-provider-0.19.1
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 0.36.2
#     Uninstalling qiskit-0.36.2:
#       Successfully uninstalled qiskit-0.36.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-qiskit 0.26.0 requires qiskit~=0.36.0, but you have qiskit 0.37.0 which is incompatible.
# Successfully installed mthree-1.0.0 orjson-3.7.8 pennylane-qiskit-0.24.0 qiskit-0.37.0 qiskit-ibmq-provider-0.19.2 qiskit-terra-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import qasm3

# Make a new qnode targeted to the Qiskit Aer Simulator backend
dev = qml.device("qiskit.aer", wires = n_qubits)
qnode = qml.QNode(circ, dev)

# Running it once implicitly converts it to a Qiskit Circuit object, which allows us to dump OpenQASM
qnode([1.0], [1.0])

# OpenQASM2: dev._circuit.qasm(formatted=True)
print(qasm3.dumps(dev._circuit))

# Now, we run it with the new parameters generated by the optimizer above
qnode([.5], [1.5])

print(qasm3.dumps(dev._circuit))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       1 from qiskit import qasm3
#       3 # Make a new qnode targeted to the Qiskit Aer Simulator backend
# ----> 4 dev = qml.device("qiskit.aer", wires = n_qubits)
#       5 qnode = qml.QNode(circ, dev)
#       7 # Running it once implicitly converts it to a Qiskit Circuit object, which allows us to dump OpenQASM
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pennylane/__init__.py:307, in device(name, *args, **kwargs)
#     304 options.update(kwargs)
#     306 # loads the device class
# --> 307 plugin_device_class = plugin_devices[name].load()
#     309 if Version(version()) not in Spec(plugin_device_class.pennylane_requires):
#     310     raise DeviceError(
#     311         f"The {name} plugin requires PennyLane versions {plugin_device_class.pennylane_requires}, "
#     312         f"however PennyLane version {__version__} is installed."
#     313     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:2458, in EntryPoint.load(self, require, *args, **kwargs)
#    2456 if require:
#    2457     self.require(*args, **kwargs)
# -> 2458 return self.resolve()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:2464, in EntryPoint.resolve(self)
#    2460 def resolve(self):
#    2461     """
#    2462     Resolve the entry point from its module and attrs.
#    2463     """
# -> 2464     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#    2465     try:
#    2466         return functools.reduce(getattr, self.attrs, module)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pennylane_qiskit/__init__.py:19, in <module>
#      17 from .aer import AerDevice
#      18 from .basic_aer import BasicAerDevice
# ---> 19 from .ibmq import IBMQDevice
#      20 from .converter import load, load_qasm, load_qasm_from_file
#      21 from .runtime_devices import IBMQCircuitRunnerDevice
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pennylane_qiskit/ibmq.py:22, in <module>
#      19 import os
#      21 from qiskit import IBMQ
# ---> 22 from qiskit.providers.ibmq.exceptions import IBMQAccountError
#      24 from .qiskit_device import QiskitDevice
#      27 class IBMQDevice(QiskitDevice):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/__init__.py:88, in <module>
#      84 from datetime import datetime, timedelta
#      86 from qiskit.providers import Backend  # type: ignore[attr-defined]
# ---> 88 from .ibmqfactory import IBMQFactory
#      89 from .ibmqbackend import IBMQBackend
#      90 from .job import IBMQJob
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/ibmqfactory.py:20, in <module>
#      17 from collections import OrderedDict
#      18 import traceback
# ---> 20 from .accountprovider import AccountProvider
#      21 from .api.clients import AuthClient, VersionClient
#      22 from .credentials import Credentials, discover_credentials
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/accountprovider.py:26, in <module>
#      24 from qiskit.circuit import QuantumCircuit
#      25 from qiskit.transpiler import Layout
# ---> 26 from qiskit.providers.ibmq.runtime import runtime_job  # pylint: disable=unused-import
#      27 from qiskit.providers.ibmq import ibmqfactory  # pylint: disable=unused-import
#      29 from .api.clients import AccountClient
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/runtime/__init__.py:226, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2021.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 ==============================================
#      15 Runtime (:mod:`qiskit.providers.ibmq.runtime`)
#    (...)
#     223    RuntimeOptions
#     224 """
# --> 226 from .ibm_runtime_service import IBMRuntimeService
#     227 from .runtime_job import RuntimeJob
#     228 from .runtime_program import RuntimeProgram, ParameterNamespace
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/runtime/ibm_runtime_service.py:23, in <module>
#      20 from qiskit.providers.exceptions import QiskitBackendNotFoundError
#      21 from qiskit.providers.ibmq import accountprovider  # pylint: disable=unused-import
# ---> 23 from .runtime_job import RuntimeJob
#      24 from .runtime_program import RuntimeProgram, ParameterNamespace
#      25 from .utils import RuntimeDecoder, to_base64_string
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/runtime/runtime_job.py:29, in <module>
#      27 from .constants import API_TO_JOB_ERROR_MESSAGE, API_TO_JOB_STATUS
#      28 from .exceptions import RuntimeJobFailureError, RuntimeInvalidStateError, QiskitRuntimeError
# ---> 29 from .program.result_decoder import ResultDecoder
#      30 from ..api.clients import RuntimeClient, RuntimeWebsocketClient, WebsocketClientCloseCode
#      31 from ..exceptions import IBMQError
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/runtime/program/result_decoder.py:18, in <module>
#      15 import json
#      16 from typing import Any
# ---> 18 from qiskit.providers.ibmq.runtime.utils import RuntimeDecoder
#      21 class ResultDecoder:
#      22     """Runtime job result decoder.
#      23
#      24     You can subclass this class and overwrite the :meth:`decode` method
#    (...)
#      37     :meth:`qiskit.providers.ibmq.runtime.IBMRuntimeService.run`.
#      38     """
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/providers/ibmq/runtime/utils.py:39, in <module>
#      36 except ImportError:
#      37     HAS_SCIPY = False
# ---> 39 from qiskit.circuit import (
#      40     Instruction,
#      41     ParameterExpression,
#      42     ParameterVector,
#      43     QuantumCircuit,
#      44     QuantumRegister,
#      45     qpy_serialization,
#      46 )
#      47 from qiskit.result import Result
#      49 from qiskit.version import __version__ as _terra_version_string
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/circuit/qpy_serialization.py:18, in <module>
#      15 """Alias for Qiskit QPY import."""
#      17 # TODO deprecate this in 0.21.0
# ---> 18 from qiskit.qpy import dump, load
#      20 # For backward compatibility. Provide, Runtime, Experiment call these private functions.
#      21 from qiskit.qpy import (
#      22     _write_instruction,
#      23     _read_instruction,
#    (...)
#      26     _read_parameter_expression_v3,
#      27 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/qpy/__init__.py:948, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2021, 2022.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 ###########################################################
#      15 QPY serialization (:mod:`qiskit.qpy`)
#    (...)
#     945 .. [#f3] https://docs.python.org/3/c-api/complex.html#c.Py_complex
#     946 """
# --> 948 from .interface import dump, load
#     950 # For backward compatibility. Provide, Runtime, Experiment call these private functions.
#     951 from .binary_io import (
#     952     _write_instruction,
#     953     _read_instruction,
#    (...)
#     956     _read_parameter_expression_v3,
#     957 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/qpy/interface.py:25, in <module>
#      23 from qiskit.pulse import ScheduleBlock
#      24 from qiskit.exceptions import QiskitError
# ---> 25 from qiskit.qpy import formats, common, binary_io, type_keys
#      26 from qiskit.qpy.exceptions import QpyError
#      27 from qiskit.version import __version__
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/qpy/binary_io/__init__.py:15, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2021, 2022.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """Read and write QPY-serializable objects."""
# ---> 15 from .value import (
#      16     dumps_value,
#      17     loads_value,
#      18     write_value,
#      19     read_value,
#      20     # for backward compatibility; provider, runtime, experiment call this private methods.
#      21     _write_parameter_expression,
#      22     _read_parameter_expression,
#      23     _read_parameter_expression_v3,
#      24 )
#      26 from .circuits import (
#      27     write_circuit,
#      28     read_circuit,
#    (...)
#      31     _read_instruction,
#      32 )
#      33 from .schedules import (
#      34     write_schedule_block,
#      35     read_schedule_block,
#      36 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/qpy/binary_io/value.py:23, in <module>
#      21 from qiskit.circuit.parameterexpression import ParameterExpression
#      22 from qiskit.circuit.parametervector import ParameterVector, ParameterVectorElement
# ---> 23 from qiskit.qpy import common, formats, exceptions, type_keys
#      24 from qiskit.utils import optionals as _optional
#      27 def _write_parameter(file_obj, obj):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/qiskit/qpy/type_keys.py:48, in <module>
#      29 from qiskit.pulse.channels import (
#      30     Channel,
#      31     DriveChannel,
#    (...)
#      36     RegisterSlot,
#      37 )
#      38 from qiskit.pulse.instructions import (
#      39     Acquire,
#      40     Play,
#    (...)
#      46     RelativeBarrier,
#      47 )
# ---> 48 from qiskit.pulse.library import Waveform, SymbolicPulse
#      49 from qiskit.pulse.schedule import ScheduleBlock
#      50 from qiskit.pulse.transforms.alignments import (
#      51     AlignLeft,
#      52     AlignRight,
#      53     AlignSequential,
#      54     AlignEquispaced,
#      55 )
#
# ImportError: cannot import name 'SymbolicPulse' from 'qiskit.pulse.library' (/Users/hakanayaz/opt/anaconda3/lib/python3.9/site-packages/qiskit/pulse/library/__init__.py)

# %% [markdown]
# The [before](init.qasm) and [after](after.qasm) circuits are dumped to OpenQASM, and we note that the only difference lies in the values of the rotation gates, rather than in circuit structure.
#
# ![QASM Diff](diff.png)
#
# This is encouraging, as it suggests that a hybrid IR can re-utilize the same OpenQASM file which reaches into a single dynamic array and is updated by the classical optimizer.
